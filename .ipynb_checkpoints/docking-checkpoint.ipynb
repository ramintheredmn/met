# %%
import prody as pr
import numpy as np
import os
import subprocess
import rdkit as rd
from rdkit import Chem
from rdkit.Chem import AllChem
from tqdm.auto import tqdm
import pandas as pd
import math
from meeko import MoleculePreparation
from meeko import PDBQTWriterLegacy
from rdkit import IPythonConsole

IPythonConsole.ipython_useSVG = True

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met

# %% [markdown]
# ## helper functions

# %%
# this list is to make sure that we only use the supported charachters by autogrid
supported_atypes = ['HD', 'C', 'A', 'N', 'NA', 'OA', 'F', 'P', 'SA', 'S',
                    'Cl', 'Br', 'I', 'Mg', 'Ca', 'Mn', 'Fe', 'Zn']

# the structure of the gpf file for autogrid4 as p
gpf = """npts NPTS_X NPTS_Y NPTS_Z
gridfld r.maps.fld
spacing 0.375
receptor_types RECTYPES
ligand_types HD C A N NA OA F P SA S Cl Br I
receptor r.pdbqt
gridcenter CENTER_X CENTER_Y CENTER_Z
smooth 0.5
map         r.HD.map
map         r.C.map
map         r.A.map
map         r.N.map
map         r.NA.map
map         r.OA.map
map         r.F.map
map         r.P.map
map         r.SA.map
map         r.S.map
map         r.Cl.map
map         r.Br.map
map         r.I.map
elecmap     r.e.map
dsolvmap    r.d.map
dielectric -0.1465
"""


vina_config = """
center_x = CENTER_X
center_y = CENTER_Y
center_z = CENTER_Z
size_x = SIZE_X
size_y = SIZE_Y
size_z = SIZE_Z
"""

# %%
def getrectypes(fname):
    command = 'cut -c 77-79 %s | sort -u' % fname
    out = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
    out = out.communicate()[0]
    rectypes = []
    for atype in out.split():
        atype = atype.strip().decode()
        if atype in supported_atypes:
            rectypes.append(atype)
    return ' '.join(rectypes)


# calculating grid box from the ligand size 
def calcbox(fname, pad, spacing=0.375) -> list:
    x_min = float('inf')
    y_min = float('inf')
    z_min = float('inf')
    x_max = float('-inf')
    y_max = float('-inf')
    z_max = float('-inf')
    with open(fname) as f:
        for line in f:
            if line.startswith('ATOM') or line.startswith('HETATM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                x_max = max(x, x_max)
                y_max = max(y, y_max)
                z_max = max(z, z_max)
                x_min = min(x, x_min)
                y_min = min(y, y_min)
                z_min = min(z, z_min)
    center_x = (x_min + x_max) / 2.0
    center_y = (y_min + y_max) / 2.0
    center_z = (z_min + z_max) / 2.0
    npts_x = math.ceil((2 * pad + x_max - x_min) / spacing)  
    npts_y = math.ceil((2 * pad + y_max - y_min) / spacing)  
    npts_z = math.ceil((2 * pad + z_max - z_min) / spacing)  
    return [center_x, center_y, center_z, npts_x, npts_y, npts_z]


# this function writes the grid info for vina, vina algo dont accept map
def vina_conf(center_x, center_y, center_z,npts_x, npts_y, npts_z) -> list:
    center_x = center_x
    center_y = center_y
    center_z = center_z
    size_x = (npts_x * 0.75) / 2
    size_y = (npts_y * 0.75) / 2
    size_z = (npts_z * 0.75) / 2
    return [center_x, center_y, center_z, size_x, size_y, size_z]



def write_vinaconf_gpf(lPDBQT, rPDBQT, p, gpf=gpf, vconf=vina_config, gpf_out='./r.gpf', v_out='./v.txt'):
    rrectypes = getrectypes(rPDBQT)
    gridbox: list = calcbox(lPDBQT, p)
    vina_config: list = vina_conf(*gridbox)


    gpf = gpf.replace('RECTYPES',   rrectypes)
    gpf = gpf.replace('NPTS_X',     '%d' % gridbox[3])
    gpf = gpf.replace('NPTS_Y',     '%d' % gridbox[4])
    gpf = gpf.replace('NPTS_Z',     '%d' % gridbox[5])
    gpf = gpf.replace('CENTER_X',   '%.3f' % gridbox[0])
    gpf = gpf.replace('CENTER_Y',   '%.3f' % gridbox[1])
    gpf = gpf.replace('CENTER_Z',   '%.3f' % gridbox[2])
    
    vconf = vconf.replace('CENTER_X',   '%d' % vina_config[0])
    vconf = vconf.replace('CENTER_Y',   '%d' % vina_config[1])
    vconf = vconf.replace('CENTER_Z',   '%d' % vina_config[2])
    vconf = vconf.replace('SIZE_X',     '%d' % vina_config[3])
    vconf = vconf.replace('SIZE_Y',     '%d' % vina_config[4])
    vconf = vconf.replace('SIZE_Z',     '%d' % vina_config[5])

    with open(gpf_out, 'w') as f:
        f.write(gpf)
    with open(v_out, 'w') as f:
        f.write(vconf)

def run_autogrid(gpf, glgout='./r.glg'):
    command = f'autogrid4 -p {gpf} -l {glgout}'
    subprocess.run(command ,shell=True, stdout=subprocess.PIPE)
    print('success, map files created sucsussfully!')
    return 1

def run_prepare_receptor(rPDB):
    command = f'prepare_receptor -r {rPDB} -o r.pdbqt'
    try:
        subprocess.run(command, shell=True, stdout=subprocess.PIPE)
        print("success")
        return 1
    except Exception as e:
        print(f"error:{str(e)}")
        return 0

def run_obabel_ligand(lPDB):
    command_1 = f'obabel -ipdb {lPDB} -osdf -O ./l_with_no_h.sdf'
    subprocess.run(command_1, shell=True, stdout=subprocess.PIPE)
    return 1

def run_prepare_ligand(lSDF):
    command = f'mk_prepare_ligand.py -i {lSDF} -o l.pdbqt'
    subprocess.run(command, shell=True, stdout=subprocess.PIPE)
    return 1

def obabel_receptor(rPDB):
    command = f'obabel -i pdb {rPDB} -opdb -O ./r.pdb -h'
    subprocess.run(command, shell=True, stdout=subprocess.PIPE)
    return 1

# %%
def prepare_lig_rec(this_time, out=("./r.pdb", "./l.pdb")):
    mainPbd = pr.parsePDB(pr.fetchPDB(this_time, compressed=False)) # fetches the pdb file
    chains = mainPbd.getChids() # seprates the chain
    receptor = mainPbd.select('chain A protein') # lets hope there's always a A chain!
    pr.writePDB(out[0], receptor) # save the chain A as r.pdb
    # I encountered some problems with rdkit adding Hs to rec I decided to use obabel with -h flag
    # mol = rd.Chem.MolFromPDBFile('./r.pdb') # load the r.pdb in order to add hydrogens
    # receptor_H = rd.Chem.AddHs(mol, addCoords=True, addResidueInfo=True) # add Hs
    # rd.Chem.PDBWriter('./r.pdb').write(receptor_H) # write the hydrogenated r.pdb
    obabel_receptor(out[0])
    try:
        ligands = mainPbd.select('chain A not protein not water') # seprate the small molecules
        res, count = np.unique(ligands.getResnames(), return_counts=True) # as my experience the most reapeted name in .getResname method output is the main ligand 
        dict_res_count = dict(zip(res, count)) # create a dict from the resnames and there count
        main_res = list(dict_res_count.keys())[list(dict_res_count.values()).index(max(dict_res_count.values()))] # chose the most reapeted one
        ligand = ligands.select(f'resname {main_res}')
        pr.writePDB(out[1], ligand)
    except:
        return "No ligands"

# %%
def addHs(input_sdf, output_sdf): ## to ligand
    try:
        suppl = rd.Chem.SDMolSupplier(input_sdf, sanitize=False)
        mol = next(suppl)
        for atom in mol.GetAtoms():
            if atom.GetAtomicNum() == 7 and atom.GetTotalValence() == 4: # 7fcz
                atom.SetFormalCharge(1)  # Assuming it's supposed to be NH4+
        rd.Chem.SanitizeMol(mol)  # Re-sanitize after making adjustments

        ligand_H = rd.Chem.AddHs(mol, addCoords=True)
        
        writer = rd.Chem.SDWriter(output_sdf)
        writer.write(ligand_H)
        writer.close()
        print("now the small molecule has Hs")
        return 1
    except Exception as e:
        print(f"an error occured, {str(e)}")

# %%
os.getcwd()
# Out:
# '/home/ramin/Desktop/personal/cheminfo/met'

# %%
os.chdir("./savolotinib_6SDE_lgbm//")

# %%
def ligand_prep(ligmol, out):
    '''
    input:
    :ligmol: RDkit mol
    :out: output path and name
    output:
    :pdbqt: writes a pdbfile to the working directory
    '''
    mol_Hs = Chem.AddHs(ligmol, addCoords=True)
    AllChem.EmbedMolecule(mol_Hs, AllChem.ETKDG())
    AllChem.MMFFOptimizeMolecule(mol_Hs)
    preparator = MoleculePreparation(merge_these_atom_types=("H",))
    mol_setup = preparator.prepare(mol_Hs)[0]
    pdbqt_string, is_ok, error_msg = PDBQTWriterLegacy.write_string(mol_setup)
    if is_ok:
            #print(type(pdbqt_string) ,pdbqt_string, end="")
        with open(f'{out}.pdbqt', 'w') as pdbqt:
            pdbqt.writelines(pdbqt_string)
        return 1
    if not is_ok:
        return 0, str(error_msg)

# %% [markdown]
# ## main part

# %% [markdown]
# ### validation

# %%
prepare_lig_rec("2wkm", out=("./wild/r.pdb", "./wild/l.pdb"))
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 2wkm downloaded (2wkm.pdb)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 2492 atoms and 1 coordinate set(s) were parsed in 0.02s.
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./wild/r.pdb)
#
# 1 molecule converted

# %%
os.chdir("../wild")

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/wild

# %%
! prepare_receptor -r r.pdb -o r.pdbqt
# Out:
# adding gasteiger charges to peptide

# %%
run_obabel_ligand('./l.pdb')
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./l.pdb)
#
# 1 molecule converted
# 1

# %%
addHs('./l_with_no_h.sdf', 'l_out.sdf')
# Out:
# now the small molecule has Hs
# 1

# %%
run_prepare_ligand('./l_out.sdf')
# Out:
# 1

# %%
write_vinaconf_gpf('l.pdbqt', 'r.pdbqt', 10)

# %%
! obabel -i pdb ../r.pdb -opdb -O ./r.pdb -h
# Out:
# 1 molecule converted

# %%
! prepare_receptor -r r.pdb -o r.pdbqt
# Out:
# adding gasteiger charges to peptide

# %%
write_vinaconf_gpf('l.pdbqt', 'r.pdbqt', 10)

# %%
! autogrid4 -p r.gpf -l r.glg

# %%
! adgpu --lfile l.pdbqt --ffile r.maps.fld --nrun 50
# Out:
# AutoDock-GPU version: v1.5.3-104-g2e658c318d60806bc6bb361f11f8535d5fb1fe1f
#
# Running 1 docking calculation
#
# Cuda device:                              NVIDIA GeForce MX450
# Available memory on device:               1627 MB (total: 1685 MB)
#
# CUDA Setup time 0.224820s
# (Thread 6 is setting up Job #1)
#
# Running Job #1
#     Using heuristics: (capped) number of evaluations set to 702259
#     Local-search chosen method is: ADADELTA (ad)
#
# Rest of Setup time 0.038241s
#
# Executing docking runs, stopping automatically after either reaching 0.15 kcal/mol standard deviation of
# the best molecules of the last 4 * 5 generations, 42000 generations, or 702259 evaluations:
#
# Generations |  Evaluations |     Threshold    |  Average energy of best 10%  | Samples | Best Inter + Intra
# ------------+--------------+------------------+------------------------------+---------+-------------------
#           0 |          150 |   -0.85 kcal/mol |   -3.13 +/-    0.61 kcal/mol |       4 |   -4.03 kcal/mol
#           5 |        64521 |   -0.85 kcal/mol |   -9.57 +/-    2.44 kcal/mol |    2265 |  -19.07 kcal/mol
#          10 |       149469 |   -9.55 kcal/mol |  -15.88 +/-    1.18 kcal/mol |     181 |  -19.31 kcal/mol
#          15 |       256315 |  -15.78 kcal/mol |  -18.82 +/-    0.37 kcal/mol |      33 |  -19.40 kcal/mol
#          20 |       380058 |  -18.65 kcal/mol |  -19.27 +/-    0.16 kcal/mol |      17 |  -19.50 kcal/mol
#          25 |       514680 |  -19.13 kcal/mol |  -19.31 +/-    0.12 kcal/mol |      18 |  -19.50 kcal/mol
#          30 |       652430 |  -19.20 kcal/mol |  -19.40 +/-    0.10 kcal/mol |      25 |  -19.52 kcal/mol
#          32 |       708121 |  -19.33 kcal/mol |  -19.46 +/-    0.06 kcal/mol |      37 |  -19.52 kcal/mol
# ------------+--------------+------------------+------------------------------+---------+-------------------
#
#                                    Finished evaluation after reaching
#                         708121 evaluations. Best inter + intra   -19.52 kcal/mol.
#
#
# Shutdown time 0.001198s
#
# Job #1 took 14.183 sec after waiting 0.485 sec for setup
#
# (Thread 6 is processing Job #1)
# Run time of entire job set (1 file): 14.813 sec
# Processing time: 0.145 sec
#
# All jobs ran without errors.

# %%
os.chdir("../mutant/")

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/mutant

# %%
obabel_receptor('/home/ramin/Downloads/results_20241011-1434-AC75EF/mutant_structures/2wkm_m.pdb')
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /home/ramin/Downloads/results_20241011-1434-AC75EF/mutant_structures/2wkm_m.pdb)
#
# 1 molecule converted
# 1

# %%
! prepare_receptor -r r.pdb -o r.pdbqt
# Out:
# adding gasteiger charges to peptide

# %%
write_vinaconf_gpf('../wild/l.pdbqt', 'r.pdbqt', 10)

# %%
! autogrid4 -p r.gpf -l r.glg

# %%
! cp ../wild/l.pdbqt ./

# %%
! adgpu --lfile l.pdbqt --ffile r.maps.fld --nrun 50
# Out:
# AutoDock-GPU version: v1.5.3-104-g2e658c318d60806bc6bb361f11f8535d5fb1fe1f
#
# Running 1 docking calculation
#
# Cuda device:                              NVIDIA GeForce MX450
# Available memory on device:               1627 MB (total: 1685 MB)
#
# CUDA Setup time 0.218950s
# (Thread 6 is setting up Job #1)
#
# Running Job #1
#     Using heuristics: (capped) number of evaluations set to 702259
#     Local-search chosen method is: ADADELTA (ad)
#
# Rest of Setup time 0.036315s
#
# Executing docking runs, stopping automatically after either reaching 0.15 kcal/mol standard deviation of
# the best molecules of the last 4 * 5 generations, 42000 generations, or 702259 evaluations:
#
# Generations |  Evaluations |     Threshold    |  Average energy of best 10%  | Samples | Best Inter + Intra
# ------------+--------------+------------------+------------------------------+---------+-------------------
#           0 |          150 |   -2.62 kcal/mol |   -3.45 +/-    0.22 kcal/mol |       4 |   -3.81 kcal/mol
#           5 |        62255 |   -2.62 kcal/mol |   -9.68 +/-    2.56 kcal/mol |    2103 |  -17.18 kcal/mol
#          10 |       144588 |   -9.66 kcal/mol |  -15.95 +/-    0.88 kcal/mol |     197 |  -18.58 kcal/mol
#          15 |       248958 |  -15.88 kcal/mol |  -18.16 +/-    0.40 kcal/mol |      39 |  -18.94 kcal/mol
#          20 |       369710 |  -18.00 kcal/mol |  -18.81 +/-    0.12 kcal/mol |      18 |  -19.05 kcal/mol
#          25 |       497860 |  -18.71 kcal/mol |  -18.88 +/-    0.13 kcal/mol |      27 |  -19.10 kcal/mol
#          30 |       631446 |  -18.81 kcal/mol |  -18.97 +/-    0.10 kcal/mol |      21 |  -19.10 kcal/mol
#          33 |       712013 |  -18.89 kcal/mol |  -19.04 +/-    0.05 kcal/mol |      28 |  -19.10 kcal/mol
# ------------+--------------+------------------+------------------------------+---------+-------------------
#
#                                    Finished evaluation after reaching
#                         712013 evaluations. Best inter + intra   -19.10 kcal/mol.
#
#
# Shutdown time 0.001136s
#
# Job #1 took 14.278 sec after waiting 0.475 sec for setup
#
# (Thread 6 is processing Job #1)
# Run time of entire job set (1 file): 14.892 sec
# Processing time: 0.139 sec
#
# All jobs ran without errors.

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/mutant

# %%
drug_df = pd.read_csv("../all_fda_approved.csv")

# %%
drug_df.head()
# Out:
#   molecule_chembl_id                                            SMILES  \
# 0            CHEMBL2     COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 1            CHEMBL3                              CN1CCC[C@H]1c1cccnc1
# 2            CHEMBL4  CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 3            CHEMBL5                   CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 4            CHEMBL6    COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
#
#              name
# 0        PRAZOSIN
# 1        NICOTINE
# 2       OFLOXACIN
# 3  NALIDIXIC ACID
# 4    INDOMETHACIN

# %%
with open("./drugs_smi.smi", "w") as f:
    f.writelines((f"{i}\n" for i in drug_df.SMILES.values))

# %%
! ../gypsum_dl/run_gypsum_dl.py --source ./cleaner_drugs.smi --skip_making_tautomers --skip_enumerate_chiral_mol --skip_enumerate_double_bonds --skip_alternate_ring_conformations --job_manager multiprocessing --num_processors 4 -m 1
# Out:
# If you use Gypsum-DL in your research, please cite:
#
# Ropp, Patrick J., Jacob O. Spiegel, Jennifer L. Walker, Harrison Green,
# Guillermo A. Morales, Katherine A. Milliken, John J. Ringe, and Jacob D. Durrant.
# (2019) Gypsum-DL: An Open-source Program for Preparing Small-molecule Libraries for
# Structure-based Virtual Screening. Journal of Cheminformatics 11:1.
# doi:10.1186/s13321-019-0358-3.
#
# WARNING: Running Gypsum-DL without the Durrant-lab filters. In looking over many
#     Gypsum-DL-generated variants, we have identified a number of substructures
#     that, though technically possible, strike us as improbable or otherwise
#     poorly suited for virtual screening. We strongly recommend removing these by
#     running Gypsum-DL with the --use_durrant_lab_filters option.
#
# Loading molecules from cleaner_drugs.smi...
#     Untitled ligand on line 1. Naming that ligand untitled_line_1. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 2. Naming that ligand untitled_line_2. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 3. Naming that ligand untitled_line_3. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 4. Naming that ligand untitled_line_4. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 5. Naming that ligand untitled_line_5. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 6. Naming that ligand untitled_line_6. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 7. Naming that ligand untitled_line_7. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 8. Naming that ligand untitled_line_8. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 9. Naming that ligand untitled_line_9. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 10. Naming that ligand untitled_line_10. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 11. Naming that ligand untitled_line_11. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 12. Naming that ligand untitled_line_12. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 13. Naming that ligand untitled_line_13. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 14. Naming that ligand untitled_line_14. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 15. Naming that ligand untitled_line_15. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 16. Naming that ligand untitled_line_16. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 17. Naming that ligand untitled_line_17. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 18. Naming that ligand untitled_line_18. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 19. Naming that ligand untitled_line_19. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 20. Naming that ligand untitled_line_20. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 21. Naming that ligand untitled_line_21. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 22. Naming that ligand untitled_line_22. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 23. Naming that ligand untitled_line_23. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 24. Naming that ligand untitled_line_24. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 25. Naming that ligand untitled_line_25. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 26. Naming that ligand untitled_line_26. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 27. Naming that ligand untitled_line_27. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 28. Naming that ligand untitled_line_28. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 29. Naming that ligand untitled_line_29. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 30. Naming that ligand untitled_line_30. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 31. Naming that ligand untitled_line_31. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 32. Naming that ligand untitled_line_32. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 33. Naming that ligand untitled_line_33. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 34. Naming that ligand untitled_line_34. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 35. Naming that ligand untitled_line_35. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 36. Naming that ligand untitled_line_36. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 37. Naming that ligand untitled_line_37. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 38. Naming that ligand untitled_line_38. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 39. Naming that ligand untitled_line_39. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 40. Naming that ligand untitled_line_40. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 41. Naming that ligand untitled_line_41. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 42. Naming that ligand untitled_line_42. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 43. Naming that ligand untitled_line_43. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 44. Naming that ligand untitled_line_44. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 45. Naming that ligand untitled_line_45. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 46. Naming that ligand untitled_line_46. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 47. Naming that ligand untitled_line_47. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 48. Naming that ligand untitled_line_48. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 49. Naming that ligand untitled_line_49. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 50. Naming that ligand untitled_line_50. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 51. Naming that ligand untitled_line_51. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 52. Naming that ligand untitled_line_52. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 53. Naming that ligand untitled_line_53. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 54. Naming that ligand untitled_line_54. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 55. Naming that ligand untitled_line_55. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 56. Naming that ligand untitled_line_56. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 57. Naming that ligand untitled_line_57. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 58. Naming that ligand untitled_line_58. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 59. Naming that ligand untitled_line_59. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 60. Naming that ligand untitled_line_60. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 61. Naming that ligand untitled_line_61. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 62. Naming that ligand untitled_line_62. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 63. Naming that ligand untitled_line_63. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 64. Naming that ligand untitled_line_64. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 65. Naming that ligand untitled_line_65. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 66. Naming that ligand untitled_line_66. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 67. Naming that ligand untitled_line_67. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 68. Naming that ligand untitled_line_68. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 69. Naming that ligand untitled_line_69. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 70. Naming that ligand untitled_line_70. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 71. Naming that ligand untitled_line_71. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 72. Naming that ligand untitled_line_72. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 73. Naming that ligand untitled_line_73. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 74. Naming that ligand untitled_line_74. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 75. Naming that ligand untitled_line_75. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 76. Naming that ligand untitled_line_76. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 77. Naming that ligand untitled_line_77. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 78. Naming that ligand untitled_line_78. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 79. Naming that ligand untitled_line_79. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 80. Naming that ligand untitled_line_80. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 81. Naming that ligand untitled_line_81. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 82. Naming that ligand untitled_line_82. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 83. Naming that ligand untitled_line_83. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 84. Naming that ligand untitled_line_84. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 85. Naming that ligand untitled_line_85. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 86. Naming that ligand untitled_line_86. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 87. Naming that ligand untitled_line_87. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 88. Naming that ligand untitled_line_88. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 89. Naming that ligand untitled_line_89. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 90. Naming that ligand untitled_line_90. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 91. Naming that ligand untitled_line_91. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 92. Naming that ligand untitled_line_92. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 93. Naming that ligand untitled_line_93. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 94. Naming that ligand untitled_line_94. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 95. Naming that ligand untitled_line_95. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 96. Naming that ligand untitled_line_96. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 97. Naming that ligand untitled_line_97. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 98. Naming that ligand untitled_line_98. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 99. Naming that ligand untitled_line_99. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 100. Naming that ligand untitled_line_100. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 101. Naming that ligand untitled_line_101. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 102. Naming that ligand untitled_line_102. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 103. Naming that ligand untitled_line_103. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 104. Naming that ligand untitled_line_104. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 105. Naming that ligand untitled_line_105. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 106. Naming that ligand untitled_line_106. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 107. Naming that ligand untitled_line_107. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 108. Naming that ligand untitled_line_108. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 109. Naming that ligand untitled_line_109. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 110. Naming that ligand untitled_line_110. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 111. Naming that ligand untitled_line_111. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 112. Naming that ligand untitled_line_112. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 113. Naming that ligand untitled_line_113. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 114. Naming that ligand untitled_line_114. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 115. Naming that ligand untitled_line_115. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 116. Naming that ligand untitled_line_116. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 117. Naming that ligand untitled_line_117. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 118. Naming that ligand untitled_line_118. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 119. Naming that ligand untitled_line_119. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 120. Naming that ligand untitled_line_120. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 121. Naming that ligand untitled_line_121. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 122. Naming that ligand untitled_line_122. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 123. Naming that ligand untitled_line_123. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 124. Naming that ligand untitled_line_124. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 125. Naming that ligand untitled_line_125. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 126. Naming that ligand untitled_line_126. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 127. Naming that ligand untitled_line_127. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 128. Naming that ligand untitled_line_128. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 129. Naming that ligand untitled_line_129. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 130. Naming that ligand untitled_line_130. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 131. Naming that ligand untitled_line_131. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 132. Naming that ligand untitled_line_132. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 133. Naming that ligand untitled_line_133. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 134. Naming that ligand untitled_line_134. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 135. Naming that ligand untitled_line_135. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 136. Naming that ligand untitled_line_136. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 137. Naming that ligand untitled_line_137. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 138. Naming that ligand untitled_line_138. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 139. Naming that ligand untitled_line_139. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 140. Naming that ligand untitled_line_140. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 141. Naming that ligand untitled_line_141. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 142. Naming that ligand untitled_line_142. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 143. Naming that ligand untitled_line_143. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 144. Naming that ligand untitled_line_144. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 145. Naming that ligand untitled_line_145. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 146. Naming that ligand untitled_line_146. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 147. Naming that ligand untitled_line_147. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 148. Naming that ligand untitled_line_148. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 149. Naming that ligand untitled_line_149. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 150. Naming that ligand untitled_line_150. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 151. Naming that ligand untitled_line_151. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 152. Naming that ligand untitled_line_152. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 153. Naming that ligand untitled_line_153. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 154. Naming that ligand untitled_line_154. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 155. Naming that ligand untitled_line_155. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 156. Naming that ligand untitled_line_156. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 157. Naming that ligand untitled_line_157. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 158. Naming that ligand untitled_line_158. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 159. Naming that ligand untitled_line_159. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 160. Naming that ligand untitled_line_160. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 161. Naming that ligand untitled_line_161. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 162. Naming that ligand untitled_line_162. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 163. Naming that ligand untitled_line_163. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 164. Naming that ligand untitled_line_164. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 165. Naming that ligand untitled_line_165. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 166. Naming that ligand untitled_line_166. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 167. Naming that ligand untitled_line_167. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 168. Naming that ligand untitled_line_168. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 169. Naming that ligand untitled_line_169. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 170. Naming that ligand untitled_line_170. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 171. Naming that ligand untitled_line_171. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 172. Naming that ligand untitled_line_172. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 173. Naming that ligand untitled_line_173. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 174. Naming that ligand untitled_line_174. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 175. Naming that ligand untitled_line_175. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 176. Naming that ligand untitled_line_176. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 177. Naming that ligand untitled_line_177. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 178. Naming that ligand untitled_line_178. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 179. Naming that ligand untitled_line_179. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 180. Naming that ligand untitled_line_180. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 181. Naming that ligand untitled_line_181. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 182. Naming that ligand untitled_line_182. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 183. Naming that ligand untitled_line_183. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 184. Naming that ligand untitled_line_184. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 185. Naming that ligand untitled_line_185. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 186. Naming that ligand untitled_line_186. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 187. Naming that ligand untitled_line_187. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 188. Naming that ligand untitled_line_188. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 189. Naming that ligand untitled_line_189. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 190. Naming that ligand untitled_line_190. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 191. Naming that ligand untitled_line_191. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 192. Naming that ligand untitled_line_192. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 193. Naming that ligand untitled_line_193. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 194. Naming that ligand untitled_line_194. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 195. Naming that ligand untitled_line_195. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 196. Naming that ligand untitled_line_196. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 197. Naming that ligand untitled_line_197. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 198. Naming that ligand untitled_line_198. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 199. Naming that ligand untitled_line_199. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 200. Naming that ligand untitled_line_200. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 201. Naming that ligand untitled_line_201. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 202. Naming that ligand untitled_line_202. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 203. Naming that ligand untitled_line_203. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 204. Naming that ligand untitled_line_204. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 205. Naming that ligand untitled_line_205. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 206. Naming that ligand untitled_line_206. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 207. Naming that ligand untitled_line_207. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 208. Naming that ligand untitled_line_208. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 209. Naming that ligand untitled_line_209. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 210. Naming that ligand untitled_line_210. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 211. Naming that ligand untitled_line_211. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 212. Naming that ligand untitled_line_212. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 213. Naming that ligand untitled_line_213. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 214. Naming that ligand untitled_line_214. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 215. Naming that ligand untitled_line_215. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 216. Naming that ligand untitled_line_216. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 217. Naming that ligand untitled_line_217. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 218. Naming that ligand untitled_line_218. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 219. Naming that ligand untitled_line_219. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 220. Naming that ligand untitled_line_220. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 221. Naming that ligand untitled_line_221. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 222. Naming that ligand untitled_line_222. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 223. Naming that ligand untitled_line_223. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 224. Naming that ligand untitled_line_224. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 225. Naming that ligand untitled_line_225. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 226. Naming that ligand untitled_line_226. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 227. Naming that ligand untitled_line_227. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 228. Naming that ligand untitled_line_228. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 229. Naming that ligand untitled_line_229. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 230. Naming that ligand untitled_line_230. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 231. Naming that ligand untitled_line_231. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 232. Naming that ligand untitled_line_232. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 233. Naming that ligand untitled_line_233. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 234. Naming that ligand untitled_line_234. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 235. Naming that ligand untitled_line_235. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 236. Naming that ligand untitled_line_236. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 237. Naming that ligand untitled_line_237. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 238. Naming that ligand untitled_line_238. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 239. Naming that ligand untitled_line_239. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 240. Naming that ligand untitled_line_240. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 241. Naming that ligand untitled_line_241. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 242. Naming that ligand untitled_line_242. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 243. Naming that ligand untitled_line_243. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 244. Naming that ligand untitled_line_244. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 245. Naming that ligand untitled_line_245. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 246. Naming that ligand untitled_line_246. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 247. Naming that ligand untitled_line_247. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 248. Naming that ligand untitled_line_248. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 249. Naming that ligand untitled_line_249. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 250. Naming that ligand untitled_line_250. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 251. Naming that ligand untitled_line_251. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 252. Naming that ligand untitled_line_252. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 253. Naming that ligand untitled_line_253. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 254. Naming that ligand untitled_line_254. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 255. Naming that ligand untitled_line_255. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 256. Naming that ligand untitled_line_256. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 257. Naming that ligand untitled_line_257. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 258. Naming that ligand untitled_line_258. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 259. Naming that ligand untitled_line_259. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 260. Naming that ligand untitled_line_260. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 261. Naming that ligand untitled_line_261. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 262. Naming that ligand untitled_line_262. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 263. Naming that ligand untitled_line_263. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 264. Naming that ligand untitled_line_264. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 265. Naming that ligand untitled_line_265. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 266. Naming that ligand untitled_line_266. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 267. Naming that ligand untitled_line_267. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 268. Naming that ligand untitled_line_268. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 269. Naming that ligand untitled_line_269. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 270. Naming that ligand untitled_line_270. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 271. Naming that ligand untitled_line_271. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 272. Naming that ligand untitled_line_272. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 273. Naming that ligand untitled_line_273. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 274. Naming that ligand untitled_line_274. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 275. Naming that ligand untitled_line_275. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 276. Naming that ligand untitled_line_276. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 277. Naming that ligand untitled_line_277. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 278. Naming that ligand untitled_line_278. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 279. Naming that ligand untitled_line_279. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 280. Naming that ligand untitled_line_280. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 281. Naming that ligand untitled_line_281. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 282. Naming that ligand untitled_line_282. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 283. Naming that ligand untitled_line_283. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 284. Naming that ligand untitled_line_284. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 285. Naming that ligand untitled_line_285. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 286. Naming that ligand untitled_line_286. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 287. Naming that ligand untitled_line_287. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 288. Naming that ligand untitled_line_288. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 289. Naming that ligand untitled_line_289. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 290. Naming that ligand untitled_line_290. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 291. Naming that ligand untitled_line_291. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 292. Naming that ligand untitled_line_292. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 293. Naming that ligand untitled_line_293. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 294. Naming that ligand untitled_line_294. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 295. Naming that ligand untitled_line_295. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 296. Naming that ligand untitled_line_296. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 297. Naming that ligand untitled_line_297. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 298. Naming that ligand untitled_line_298. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 299. Naming that ligand untitled_line_299. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 300. Naming that ligand untitled_line_300. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 301. Naming that ligand untitled_line_301. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 302. Naming that ligand untitled_line_302. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 303. Naming that ligand untitled_line_303. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 304. Naming that ligand untitled_line_304. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 305. Naming that ligand untitled_line_305. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 306. Naming that ligand untitled_line_306. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 307. Naming that ligand untitled_line_307. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 308. Naming that ligand untitled_line_308. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 309. Naming that ligand untitled_line_309. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 310. Naming that ligand untitled_line_310. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 311. Naming that ligand untitled_line_311. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 312. Naming that ligand untitled_line_312. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 313. Naming that ligand untitled_line_313. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 314. Naming that ligand untitled_line_314. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 315. Naming that ligand untitled_line_315. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 316. Naming that ligand untitled_line_316. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 317. Naming that ligand untitled_line_317. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 318. Naming that ligand untitled_line_318. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 319. Naming that ligand untitled_line_319. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 320. Naming that ligand untitled_line_320. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 321. Naming that ligand untitled_line_321. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 322. Naming that ligand untitled_line_322. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 323. Naming that ligand untitled_line_323. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 324. Naming that ligand untitled_line_324. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 325. Naming that ligand untitled_line_325. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 326. Naming that ligand untitled_line_326. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 327. Naming that ligand untitled_line_327. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 328. Naming that ligand untitled_line_328. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 329. Naming that ligand untitled_line_329. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 330. Naming that ligand untitled_line_330. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 331. Naming that ligand untitled_line_331. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 332. Naming that ligand untitled_line_332. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 333. Naming that ligand untitled_line_333. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 334. Naming that ligand untitled_line_334. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 335. Naming that ligand untitled_line_335. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 336. Naming that ligand untitled_line_336. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 337. Naming that ligand untitled_line_337. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 338. Naming that ligand untitled_line_338. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 339. Naming that ligand untitled_line_339. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 340. Naming that ligand untitled_line_340. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 341. Naming that ligand untitled_line_341. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 342. Naming that ligand untitled_line_342. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 343. Naming that ligand untitled_line_343. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 344. Naming that ligand untitled_line_344. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 345. Naming that ligand untitled_line_345. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 346. Naming that ligand untitled_line_346. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 347. Naming that ligand untitled_line_347. All
#         associated files will be referred to with this name.
#     Untitled ligand on line 348. Naming that ligand untitled_line_348. All
#         associated files will be referred to with this name.
# ...
#                 cc1
#         MolContainer #1814 (untitled_line_1815)
#             Mol #0: CN1CCC(C(=O)c2cccc(NC(=O)c3c(F)cc(F)cc3F)n2)CC1
#         MolContainer #1815 (untitled_line_1816)
#             Mol #0: O=P(O)(O)OCC([O-])C[O-]
#         MolContainer #1816 (untitled_line_1817)
#             Mol #0: N#Cc1ccc([C@H]2CCc3cncn32)c(F)c1
#         MolContainer #1817 (untitled_line_1818)
#             Mol #0: O=C(NC1CCNCC1)[C@@H]1CC[C@@H]2CN1C(=O)N2OS(=O)(=O)O
#         MolContainer #1818 (untitled_line_1819)
#             Mol #0: CCOC(=O)[C@H](C)C[C@@H](Cc1ccc(-c2ccccc2)cc1)NC(=O)CCC(=O)O
#         MolContainer #1819 (untitled_line_1820)
#             Mol #0:
#                 NC(=O)c1cnc2[nH]ccc2c1N[C@@H]1[C@@H]2CC3C[C@H]1C[C@@](O)(C3)C2
#         MolContainer #1820 (untitled_line_1821)
#             Mol #0:
#                 COc1c(-c2ccc3cc(NS(C)(=O)=O)ccc3c2)cc(-
#                 n2ccc(=O)[nH]c2=O)cc1C(C)(C)C
#         MolContainer #1821 (untitled_line_1822)
#             Mol #0: Cn1ncnc1[C@H]1c2n[nH]c(=O)c3cc(F)cc(c23)N[C@@H]1c1ccc(F)cc1
#         MolContainer #1822 (untitled_line_1823)
#             Mol #0: COc1ccc2c3c1O[C@H]1C(OC(=O)c4ccccc4)=CC[C@@H]4[C@@H](C2)N(C)
#                 CC[C@@]341
#         MolContainer #1823 (untitled_line_1824)
#             Mol #0: CC(C)(C)C(=O)OCOC(=O)[C@@H]1N2C(=O)[C@@H](NC(=O)[C@H](N)c3cc
#                 ccc3)[C@H]2SC1(C)C
#         MolContainer #1824 (untitled_line_1825)
#             Mol #0: CNC(=C[N+](=O)[O-])NCCSCc1csc(CN(C)C)n1
#         MolContainer #1825 (untitled_line_1826)
#             Mol #0: CCCCC(CC)COC(=O)C=Cc1ccc(OC)cc1
#         MolContainer #1826 (untitled_line_1827)
#             Mol #0:
#                 CNC(=O)c1ccc(N2C(=S)N(c3cnc(C#N)c(C(F)(F)F)c3)C(=O)C23CCC3)cc1F
#         MolContainer #1827 (untitled_line_1828)
#             Mol #0: OCc1ccc(Cl)cc1Cl
#         MolContainer #1828 (untitled_line_1829)
#             Mol #0: CCC[C@@H]1C[C@@H](C(=O)N[C@@H]([C@H]2O[C@H](SC)[C@H](OP(=O)(
#                 O)O)[C@@H](O)[C@H]2O)[C@H](C)Cl)N(C)C1
#         MolContainer #1829 (untitled_line_1830)
#             Mol #0: CN1CC2c3ccccc3Oc3ccc(Cl)cc3C2C1
#         MolContainer #1830 (untitled_line_1831)
#             Mol #0: Cn1cnc2c(F)c(Nc3ccc(Br)cc3F)c(C(=O)NOCCO)cc21
#         MolContainer #1831 (untitled_line_1832)
#             Mol #0: CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
#         MolContainer #1832 (untitled_line_1833)
#             Mol #0: COc1c(OCCCN2CCOCC2)ccc2c1N=C(NC(=O)c1cnc(N)nc1)N1CCN=C21
#         MolContainer #1833 (untitled_line_1834)
#             Mol #0: O=C1N[C@H](O)CCN1[C@@H]1O[C@H](CO)[C@@H](O)C1(F)F
#         MolContainer #1834 (untitled_line_1835)
#             Mol #0: C[C@H]1Oc2cc(cnc2N)-c2c(nn(C)c2C#N)CN(C)C(=O)c2ccc(F)cc21
#         MolContainer #1835 (untitled_line_1836)
#             Mol #0: C=C[C@]1(C)C[C@@H](OC(=O)CS[C@@H]2CC[C@@H](N)C[C@H]2O)[C@]2(
#                 C)[C@H](C)CC[C@]3(CCC(=O)[C@H]32)[C@@H](C)[C@@H]1O
#         MolContainer #1836 (untitled_line_1837)
#             Mol #0: O=C(Nc1nc2cccc(-c3ccc(CN4CCS(=O)(=O)CC4)cc3)n2n1)C1CC1
#         MolContainer #1837 (untitled_line_1838)
#             Mol #0:
#                 CCN1CCN(Cc2ccc(Nc3ncc(F)c(-c4cc(F)c5nc(C)n(C(C)C)c5c4)n3)nc2)CC1
#         MolContainer #1838 (untitled_line_1839)
#             Mol #0: COC(=O)N[C@@H](C)CNc1nccc(-c2cn(C(C)C)nc2-
#                 c2cc(Cl)cc(NS(C)(=O)=O)c2F)n1
#         MolContainer #1839 (untitled_line_1840)
#             Mol #0:
#                 CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c(OC)c2)nc1NC1CCOCC
#                 1
#         MolContainer #1840 (untitled_line_1841)
#             Mol #0: CCCCCCCC(=O)OCC(CO)OC(=O)CCCCCCC
#         MolContainer #1841 (untitled_line_1842)
#             Mol #0: CN(C)CC(C)(C)OC(=O)C(O)(c1ccccc1)c1ccccc1
#         MolContainer #1842 (untitled_line_1843)
#             Mol #0: CN1CCN2c3c(cccc31)[C@@H]1CN(CCCC(=O)c3ccc(F)cc3)CC[C@@H]12
#         MolContainer #1843 (untitled_line_1844)
#             Mol #0:
#                 O[C@@](Cn1cnnn1)(c1ccc(F)cc1F)C(F)(F)c1ccc(-
#                 c2ccc(OCC(F)(F)F)cc2)cn1
#         MolContainer #1844 (untitled_line_1845)
#             Mol #0: O=C(O)C[C@@H]1CC[C@H](NC(=O)Cc2cccs2)B(O)O1
#         MolContainer #1845 (untitled_line_1846)
#             Mol #0: NC(=O)c1cc[n+](CC2=C(C(=O)[O-
#                 ])N3C(=O)[C@@H](NC(=O)[C@@H](c4ccccc4)S(=O)(=O)O)[C@H]3SC2)cc1
#         MolContainer #1846 (untitled_line_1847)
#             Mol #0:
#                 C=CC(=O)Nc1cc(Nc2nccc(-c3cn(C)c4ccccc34)n2)c(OC)cc1N(C)CCN(C)C
#         MolContainer #1847 (untitled_line_1848)
#             Mol #0:
#                 O=C(O)C[C@H]1CCc2c1[nH]c1ccc(OCc3ccc(C4CCCC4)c(C(F)(F)F)c3)cc21
#         MolContainer #1848 (untitled_line_1849)
#             Mol #0: Cc1cnc(C(=O)N[C@H]2CCCCC/C=C\[C@@H]3C[C@@]3(C(=O)NS(=O)(=O)C
#                 3CC3)NC(=O)[C@@H]3C[C@@H](Oc4nc5ccccc5c5ccccc45)CN3C2=O)cn1
#         MolContainer #1849 (untitled_line_1850)
#             Mol #0:
#                 CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)ccc4=O)c3)nc2)CC1
#         MolContainer #1850 (untitled_line_1851)
#             Mol #0: CCN(c1cc(-
#                 c2ccc(CN3CCOCC3)cc2)cc(C(=O)NCc2c(C)cc(C)[nH]c2=O)c1C)C1CCOCC1
#         MolContainer #1851 (untitled_line_1852)
#             Mol #0: CC(C)(CO)c1cc2cc(NC(=O)C3(c4ccc5c(c4)OC(F)(F)O5)CC3)c(F)cc2n
#                 1C[C@@H](O)CO
#         MolContainer #1852 (untitled_line_1853)
#             Mol #0: O=C(O)CNC(=O)C1C(=O)N(C2CCCCC2)C(=O)N(C2CCCCC2)C1=O
#         MolContainer #1853 (untitled_line_1854)
#             Mol #0: CN(C)C(=O)c1cc2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n1C1CCCC1
#         MolContainer #1854 (untitled_line_1855)
#             Mol #0: O=C(/C=C\n1cnc(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)n1)NNc1cnccn1
#         MolContainer #1855 (untitled_line_1856)
#             Mol #0: CC(C)(CCCCCC(O)CCCCCC(C)(C)C(=O)O)C(=O)O
#         MolContainer #1856 (untitled_line_1857)
#             Mol #0: Cc1ncc(OC[C@@]2(c3cccc(F)c3)C[C@H]2C(=O)Nc2ccc(F)cn2)c(C)n1
#         MolContainer #1857 (untitled_line_1858)
#             Mol #0: COc1cc(OC)cc(N(CCNC(C)C)c2ccc3ncc(-c4cnn(C)c4)nc3c2)c1
#         MolContainer #1858 (untitled_line_1859)
#             Mol #0: C[C@@H](Cc1ccccc1)N(C)Cc1ccccc1
#         MolContainer #1859 (untitled_line_1860)
#             Mol #0: Fc1ccc(-c2ccc3c(c2)[nH]c2ccncc23)cn1
#         MolContainer #1860 (untitled_line_1861)
#             Mol #0: N[C@@H](Cc1cc(O)c(O)cc1F)C(=O)O
#         MolContainer #1861 (untitled_line_1862)
#             Mol #0: CCC(=O)O[C@]1(C(=O)CO)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C
#                 @H]3CC[C@@]21C
#         MolContainer #1862 (untitled_line_1863)
#             Mol #0: Cc1nsc(-c2nnc3n2CCN(C(=O)c2ccc(F)cc2)[C@@H]3C)n1
#         MolContainer #1863 (untitled_line_1864)
#             Mol #0: CC[C@@H]1CN(C(=O)NCC(F)(F)F)C[C@@H]1c1cnc2cnc3[nH]ccc3n12
#         MolContainer #1864 (untitled_line_1865)
#             Mol #0: CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(F)F)c2)CC3)C1
#         MolContainer #1865 (untitled_line_1866)
#             Mol #0: O=C(O)CNC(=O)c1ncc(-c2cccc(Cl)c2)cc1O
#         MolContainer #1866 (untitled_line_1867)
#             Mol #0: CCCS(=O)(=O)N[C@H]1C[C@@H](N(C)c2ncnc3[nH]ccc23)C1
#         MolContainer #1867 (untitled_line_1868)
#             Mol #0:
#                 COc1cc(F)c(-n2c(=O)[nH]c3csc(C(=O)O)c3c2=O)cc1OCc1c(OC)ccc(F)c1F
#         MolContainer #1868 (untitled_line_1869)
#             Mol #0: C=CC(=O)N1CC[C@H](n2nc(C#Cc3cc(OC)cc(OC)c3)c3c(N)ncnc32)C1
#         MolContainer #1869 (untitled_line_1870)
#             Mol #0: CC(C)Oc1ccc(-c2nc(-c3cccc4c3CC[C@@H]4NCCO)no2)cc1C#N
#         MolContainer #1870 (untitled_line_1871)
#             Mol #0: O=C([O-])c1cc(=O)[nH]c(=O)[nH]1
#         MolContainer #1871 (untitled_line_1872)
#             Mol #0: CCC(=O)[C@@]1(O)[C@H](C)C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)
#                 C3=CC[C@@]21C
#         MolContainer #1872 (untitled_line_1873)
#             Mol #0: CC(C)(C)c1cc(-c2cc(-c3ccc(C(=O)O)cc3)ccc2OCCO)ccc1N1CCCC1
#         MolContainer #1873 (untitled_line_1874)
#             Mol #0: O[B-]1(O)OO[B-](O)(O)OO1
#         MolContainer #1874 (untitled_line_1875)
#             Mol #0:
#                 CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3)cc2)c2c(N)nccn12
#         MolContainer #1875 (untitled_line_1876)
#             Mol #0: C=C1C[C@H]2[C@@H]3CCC4=CC(=O)CC[C@@H]4[C@H]3CC[C@]2(C)[C@@]1
#                 (OC(C)=O)C(C)=O
#         MolContainer #1876 (untitled_line_1877)
#             Mol #0: C=CC(=O)Nc1cccc(Oc2nc(Nc3ccc(N4CCN(C)CC4)cc3)nc3ccsc23)c1
#         MolContainer #1877 (untitled_line_1878)
#             Mol #0: FC(F)(F)c1ccc(CNc2ccc(Cc3c[nH]c4ncc(Cl)cc34)cn2)cn1
#         MolContainer #1878 (untitled_line_1879)
#             Mol #0: CN(CCN1CCC(OC(=O)Nc2ccccc2-
#                 c2ccccc2)CC1)C(=O)c1ccc(CN2CCC(C(N)=O)CC2)cc1
#         MolContainer #1879 (untitled_line_1880)
#             Mol #0: C[N+](C)(C)CC(=O)[O-]
#         MolContainer #1880 (untitled_line_1881)
#             Mol #0: CC(C)CCON=O
#         MolContainer #1881 (untitled_line_1882)
#             Mol #0: CCCCCCCC/C=C\CCCCCCCC(=O)[O-]
#         MolContainer #1882 (untitled_line_1883)
#             Mol #0: CCC[N+]12[C@H](O)[C@@H](CC)[C@@H]3C[C@H]1[C@@H]1N(C)c4ccccc4
#                 [C@]14C[C@H]2[C@@H]3[C@H]4O
#         MolContainer #1883 (untitled_line_1884)
#             Mol #0: C[C@@H](CC(C(=O)N1CCCC1)(c1ccccc1)c1ccccc1)N1CCOCC1
#         MolContainer #1884 (untitled_line_1885)
#             Mol #0: Cl[Al](Cl)Cl
#         MolContainer #1885 (untitled_line_1886)
#             Mol #0: O=C(Nc1cnn2ccc(N3CCC[C@@H]3c3cc(F)ccc3F)nc12)N1CC[C@H](O)C1
#         MolContainer #1886 (untitled_line_1887)
#             Mol #0: CN1CCN(c2ccc(Nc3ncc4cc5n(c4n3)C3(CCCCC3)CNC5=O)nc2)CC1
#         MolContainer #1887 (untitled_line_1888)
#             Mol #0:
#                 C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-
#                 c4ccc(Oc5ccccc5)cc4)nn32)CC1
#         MolContainer #1888 (untitled_line_1889)
#             Mol #0: N[C@@H]1C[C@H]1c1ccccc1
#         MolContainer #1889 (untitled_line_1890)
#             Mol #0: CC1(C)C2CCC1(CS(=O)(=O)O)C(=O)C2=Cc1ccc(C=C2C(=O)C3(CS(=O)(=
#                 O)O)CCC2C3(C)C)cc1
#         MolContainer #1890 (untitled_line_1891)
#             Mol #0: O=C(NCc1c(F)cc(F)cc1F)c1cn2c(c(O)c1=O)C(=O)N1[C@H]3CC[C@H](C
#                 3)O[C@@H]1C2
#         MolContainer #1891 (untitled_line_1892)
#             Mol #0: Cc1cc(Nc2ncnc3ccc(NC4=NC(C)(C)CO4)cc23)ccc1Oc1ccn2ncnc2c1
#         MolContainer #1892 (untitled_line_1893)
#             Mol #0: CC(C)(O)CNc1nc(Nc2ccnc(C(F)(F)F)c2)nc(-c2cccc(C(F)(F)F)n2)n1
#         MolContainer #1893 (untitled_line_1894)
#             Mol #0: COC(=O)/C=C/C(=O)OCCN1C(=O)CCC1=O
#         MolContainer #1894 (untitled_line_1895)
#             Mol #0: NC(=O)O[C@@H](Cn1ncnn1)c1ccccc1Cl
#         MolContainer #1895 (untitled_line_1896)
#             Mol #0: N#Cc1ccnc(N2C(=O)CC[C@H]2C(=O)N(c2cncc(F)c2)[C@H](C(=O)NC2CC
#                 (F)(F)C2)c2ccccc2Cl)c1
#         MolContainer #1896 (untitled_line_1897)
#             Mol #0: CNc1ncc(-c2ccc3c(=O)c(C(=O)O)cn(C4CC4)c3c2C)cc1C
#         MolContainer #1897 (untitled_line_1898)
#             Mol #0: C[C@@H]1[C@H](c2c(F)ccc(F)c2F)C[C@H](NC(=O)c2cnc3c(c2)C[C@@]
#                 2(C3)C(=O)Nc3ncccc32)C(=O)N1CC(F)(F)F
#         MolContainer #1898 (untitled_line_1899)
#             Mol #0: COC(=O)Nc1c(N)nc(-c2nn(Cc3ccccc3F)c3ncc(F)cc23)nc1N
#         MolContainer #1899 (untitled_line_1900)
#             Mol #0:
#                 CC#CC(=O)N1CC[C@@H](n2c(=O)n(-
#                 c3ccc(Oc4ccccc4)cc3)c3c(N)ncnc32)C1
#         MolContainer #1900 (untitled_line_1901)
#             Mol #0: C=CC(=O)N1C[C@H](Nc2ncnc3[nH]ccc23)CC[C@@H]1C
#         MolContainer #1901 (untitled_line_1902)
#             Mol #0: CC(C)n1nccc1-c1ncccc1COc1cccc(O)c1C=O
#         MolContainer #1902 (untitled_line_1903)
#             Mol #0: C[C@@]1(O)CC[C@H]2[C@H](CC[C@@H]3[C@@H]2CC[C@]2(C)[C@@H](C(=
#                 O)Cn4cc(C#N)cn4)CC[C@@H]32)C1
#         MolContainer #1903 (untitled_line_1904)
#             Mol #0:
#                 Cn1cc(-
#                 c2cc3c(N4CCN(c5ncc([C@@](C)(N)c6ccc(F)cc6)cn5)CC4)ncnn3c2)cn1
#         MolContainer #1904 (untitled_line_1905)
#             Mol #0:
#                 O=C(Nc1ccc(OC(F)(F)Cl)cc1)c1cnc(N2CC[C@@H](O)C2)c(-c2cc[nH]n2)c1
#         MolContainer #1905 (untitled_line_1906)
#             Mol #0: O=C1C=CC2C(=C1)Oc1cc(O)ccc1C21OC(=O)c2ccccc21
#         MolContainer #1906 (untitled_line_1907)
#             Mol #0: CC(O)c1cc(C(=O)N[C@@H](C)Cn2ccc(-c3ccc(C#N)c(Cl)c3)n2)n[nH]1
#         MolContainer #1907 (untitled_line_1908)
#             Mol #0:
#                 CC[N+]1(C)[C@@H]2CC(OC(=O)[C@H](CO)c3ccccc3)C[C@H]1[C@@H]1O[C@@H
#                 ]12
#         MolContainer #1908 (untitled_line_1909)
#             Mol #0: COC(=O)OCOc1c2n(ccc1=O)N([C@@H]1c3ccccc3SCc3c1ccc(F)c3F)[C@@
#                 H]1COCCN1C2=O
#         MolContainer #1909 (untitled_line_1910)
#             Mol #0: CCNCCc1ccc(CN(CC)c2cc(OC)ccc2[C@@H]2CCc3cc(O)ccc3C2)cc1
#         MolContainer #1910 (untitled_line_1911)
#             Mol #0: CC(C)n1c(=O)cc(N[C@@H](C)c2ccccc2)[nH]c1=O
#         MolContainer #1911 (untitled_line_1912)
#             Mol #0:
#                 CCN1C(=O)N(c2c(F)c(OC)cc(OC)c2F)Cc2cnc3[nH]c(CN4CCOCC4)cc3c21
#         MolContainer #1912 (untitled_line_1913)
#             Mol #0: COC(=O)CC[C@@H]1N=C(c2ccccn2)c2cc(Br)ccc2-n2c(C)cnc21
#         MolContainer #1913 (untitled_line_1914)
#             Mol #0: Cc1cn2nc(-c3cc(=O)n4cc(N5CCNC6(CC6)C5)ccc4n3)cc(C)c2n1
#         MolContainer #1914 (untitled_line_1915)
#             Mol #0:
#                 COc1ccc(-n2nccn2)c(C(=O)N2CCC[C@@]2(C)c2nc3c(C)c(Cl)ccc3[nH]2)c1
#         MolContainer #1915 (untitled_line_1916)
#             Mol #0: C[C@H](Nc1ccc(C#N)n(C)c1=O)c1cc2cc(Cl)ccc2[nH]c1=O
#         MolContainer #1916 (untitled_line_1917)
#             Mol #0: NC(=O)OC[C@H](N)Cc1ccccc1
#         MolContainer #1917 (untitled_line_1918)
#             Mol #0: Cc1nn(C)cc1S(=O)(=O)NC(=O)c1ccc(-
#                 n2ccc(OCC(C)(C)C(F)(F)F)n2)nc1N1C[C@@H](C)CC1(C)C
#         MolContainer #1918 (untitled_line_1919)
#             Mol #0: CC1=C[C@@H]2CN(C(=O)N2OS(=O)(=O)O)[C@@H]1C(N)=O
#         MolContainer #1919 (untitled_line_1920)
#             Mol #0: C[C@H]1CNC(=O)c2cnn3ccc(nc23)N[C@H](C)c2cc(F)ccc2O1
#         MolContainer #1920 (untitled_line_1921)
#             Mol #0: O=C(c1ccc(NS(=O)(=O)c2cccc3cccnc23)cc1)N1CCN(CC2CC2)CC1
#         MolContainer #1921 (untitled_line_1922)
#             Mol #0: COC(=O)[C@H](c1ccccc1)[C@H]1CCCCN1C(=O)OC[n+]1cccc(C(=O)N[C@
#                 @H](CO)C(=O)O)c1
#         MolContainer #1922 (untitled_line_1923)
#             Mol #0:
#                 CCOC(=O)[C@H](Cc1ccc(F)cc1)NC(=O)[C@@H](N)Cc1ccc(N(CCCl)CCCl)cc1
#         MolContainer #1923 (untitled_line_1924)
#             Mol #0: CNC(=O)c1c(C)oc2cc(Oc3ncnc4cc(OC)c(OC)cc34)ccc12
#         MolContainer #1924 (untitled_line_1925)
#             Mol #0: C=CC(=O)N1CCN(c2nc(=O)n(-c3c(C)ccnc3C(C)C)c3nc(-
#                 c4c(O)cccc4F)c(F)cc23)[C@@H](C)C1
#         MolContainer #1925 (untitled_line_1926)
#             Mol #0:
#                 COc1ccc(CN2C3CC2CN(c2ccc(-
#                 c4cc(OCC(C)(C)O)cn5ncc(C#N)c45)cn2)C3)cn1
#         MolContainer #1926 (untitled_line_1927)
#             Mol #0: CO[C@]1(C(=O)N[C@@H](C)c2ccc(-
#                 n3cc(F)cn3)nc2)CC[C@H](c2nc(C)cc(Nc3cc(C)[nH]n3)n2)CC1
#         MolContainer #1927 (untitled_line_1928)
#             Mol #0:
#                 CS(=O)(=O)c1ccc(Oc2cc(F)cc(C#N)c2)c2c1[C@H](O)[C@H](F)[C@@H]2F
#         MolContainer #1928 (untitled_line_1929)
#             Mol #0:
#                 Cc1ccc(C(=O)OCc2ccc([C@@H](CN)C(=O)Nc3ccc4cnccc4c3)cc2)c(C)c1
#         MolContainer #1929 (untitled_line_1930)
#             Mol #0: C=C(F)C(=O)N1CCN(c2nc(OC[C@@H]3CCCN3C)nc3c2CCN(c2cccc4cccc(C
#                 l)c24)C3)C[C@@H]1CC#N
#         MolContainer #1930 (untitled_line_1931)
#             Mol #0: CNC(=O)c1nnc(NC(=O)C2CC2)cc1Nc1cccc(-c2ncn(C)n2)c1OC
#         MolContainer #1931 (untitled_line_1932)
#             Mol #0:
#                 COc1ccc(F)cc1C(=O)NCc1ccc(-
#                 c2nn([C@@H](C)C(F)(F)F)c(N)c2C(N)=O)cc1
#         MolContainer #1932 (untitled_line_1933)
#             Mol #0: CC(C)(C)[C@H](NC(=O)C(F)(F)F)C(=O)N1C[C@H]2[C@@H]([C@H]1C(=O
#                 )N[C@H](C#N)C[C@@H]1CCNC1=O)C2(C)C
# Ionizing all molecules...

# %%
prepare_lig_rec("2wgj", out=("./Crizotinib, 2wgj/wild/r.pdb", "./Crizotinib, 2wgj/wild/l.pdb"))
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 2wgj downloaded (2wgj.pdb)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 2519 atoms and 1 coordinate set(s) were parsed in 0.02s.
# ==============================
# *** Open Babel Error  in OpenAndSetFormat
#   Cannot open ./Crizotinib,
# ==============================
# *** Open Babel Error  in OpenAndSetFormat
#   Cannot open 2wgj/wild/r.pdb
# 0 molecules converted

# %%
os.chdir("./Crizotinib, 2wgj/wild")

# %%
# !pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/Crizotinib, 2wgj/wild

# %%
obabel_receptor("./r.pdb")
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./r.pdb)
#
# 1 molecule converted
# 1

# %%
! prepare_receptor -r r.pdb -o r.pdbqt
# Out:
# adding gasteiger charges to peptide

# %%
run_obabel_ligand('./l.pdb')
# Out:
# 1 molecule converted
# 1

# %%
addHs('./l_with_no_h.sdf', 'l_out.sdf')
# Out:
# now the small molecule has Hs
# 1

# %%
run_prepare_ligand('./l_out.sdf')
# Out:
# 1

# %%
write_vinaconf_gpf('l.pdbqt', 'r.pdbqt', 10)

# %%
! autogrid4 -p r.gpf -l r.glg

# %%
! adgpu --lfile l.pdbqt --ffile r.maps.fld --nrun 50
# Out:
# AutoDock-GPU version: v1.5.3-104-g2e658c318d60806bc6bb361f11f8535d5fb1fe1f
#
# Running 1 docking calculation
#
# Cuda device:                              NVIDIA GeForce MX450
# Available memory on device:               1627 MB (total: 1685 MB)
#
# CUDA Setup time 0.225939s
# (Thread 7 is setting up Job #1)
#
# Running Job #1
#     Using heuristics: (capped) number of evaluations set to 480000
#     Local-search chosen method is: ADADELTA (ad)
#
# Rest of Setup time 0.031467s
#
# Executing docking runs, stopping automatically after either reaching 0.15 kcal/mol standard deviation of
# the best molecules of the last 4 * 5 generations, 42000 generations, or 480000 evaluations:
#
# Generations |  Evaluations |     Threshold    |  Average energy of best 10%  | Samples | Best Inter + Intra
# ------------+--------------+------------------+------------------------------+---------+-------------------
#           0 |          150 |   -1.48 kcal/mol |   -2.77 +/-    0.43 kcal/mol |       5 |   -3.39 kcal/mol
#           5 |        69596 |   -1.48 kcal/mol |   -6.24 +/-    1.69 kcal/mol |    2491 |  -13.70 kcal/mol
#          10 |       157864 |   -6.23 kcal/mol |  -10.94 +/-    1.20 kcal/mol |     179 |  -13.70 kcal/mol
#          15 |       264293 |  -10.84 kcal/mol |  -13.42 +/-    0.15 kcal/mol |      30 |  -13.70 kcal/mol
#          20 |       384461 |  -13.35 kcal/mol |  -13.64 +/-    0.07 kcal/mol |      30 |  -13.75 kcal/mol
#          24 |       484929 |  -13.56 kcal/mol |  -13.67 +/-    0.07 kcal/mol |      31 |  -13.78 kcal/mol
# ------------+--------------+------------------+------------------------------+---------+-------------------
#
#                                    Finished evaluation after reaching
#                         484929 evaluations. Best inter + intra   -13.78 kcal/mol.
#
#
# Shutdown time 0.001160s
#
# Job #1 took 6.816 sec after waiting 0.420 sec for setup
#
# (Thread 7 is processing Job #1)
# Run time of entire job set (1 file): 7.320 sec
# Processing time: 0.083 sec
#
# All jobs ran without errors.

# %%
os.chdir("../mutant/")

# %%
obabel_receptor("./r.pdb")
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./r.pdb)
#
# 1 molecule converted
# 1

# %%
! prepare_receptor -r r.pdb -o r.pdbqt
# Out:
# adding gasteiger charges to peptide

# %%
! cp ../wild/l.pdbqt ./

# %%
write_vinaconf_gpf('l.pdbqt', 'r.pdbqt', 10)

# %%
! autogrid4 -p r.gpf -l r.glg

# %%
! adgpu --lfile l.pdbqt --ffile r.maps.fld --nrun 50
# Out:
# AutoDock-GPU version: v1.5.3-104-g2e658c318d60806bc6bb361f11f8535d5fb1fe1f
#
# Running 1 docking calculation
#
# Cuda device:                              NVIDIA GeForce MX450
# Available memory on device:               1627 MB (total: 1685 MB)
#
# CUDA Setup time 0.216063s
# (Thread 6 is setting up Job #1)
#
# Running Job #1
#     Using heuristics: (capped) number of evaluations set to 480000
#     Local-search chosen method is: ADADELTA (ad)
#
# Rest of Setup time 0.028372s
#
# Executing docking runs, stopping automatically after either reaching 0.15 kcal/mol standard deviation of
# the best molecules of the last 4 * 5 generations, 42000 generations, or 480000 evaluations:
#
# Generations |  Evaluations |     Threshold    |  Average energy of best 10%  | Samples | Best Inter + Intra
# ------------+--------------+------------------+------------------------------+---------+-------------------
#           0 |          150 |   -1.87 kcal/mol |   -3.06 +/-    0.32 kcal/mol |       4 |   -3.50 kcal/mol
#           5 |        72048 |   -1.87 kcal/mol |   -6.24 +/-    1.68 kcal/mol |    2744 |  -13.68 kcal/mol
#          10 |       165508 |   -6.23 kcal/mol |  -11.17 +/-    1.32 kcal/mol |     194 |  -13.79 kcal/mol
#          15 |       277103 |  -11.06 kcal/mol |  -13.63 +/-    0.13 kcal/mol |      45 |  -13.83 kcal/mol
#          20 |       400294 |  -13.59 kcal/mol |  -13.82 +/-    0.04 kcal/mol |      18 |  -13.89 kcal/mol
#          24 |       503206 |  -13.69 kcal/mol |  -13.84 +/-    0.04 kcal/mol |      19 |  -13.90 kcal/mol
# ------------+--------------+------------------+------------------------------+---------+-------------------
#
#                                    Finished evaluation after reaching
#                         503206 evaluations. Best inter + intra   -13.90 kcal/mol.
#
#
# Shutdown time 0.001402s
#
# Job #1 took 7.061 sec after waiting 0.402 sec for setup
#
# (Thread 6 is processing Job #1)
# Run time of entire job set (1 file): 7.561 sec
# Processing time: 0.098 sec
#
# All jobs ran without errors.

# %%
os.chdir("../../savolotinib_6SDE/")

# %%
prepare_lig_rec("6SDE")
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 6sde downloaded (6sde.pdb)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 2215 atoms and 1 coordinate set(s) were parsed in 0.03s.
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./r.pdb)
#
# 1 molecule converted

# %%
os.chdir("./wild")

# %%
obabel_receptor("./r.pdb")
# Out:
# 1 molecule converted
# 1

# %%
! prepare_receptor -r r.pdb -o r.pdbqt
# Out:
# adding gasteiger charges to peptide

# %%
run_obabel_ligand('./l.pdb')
# Out:
# 1 molecule converted
# 1

# %%
addHs('./l_with_no_h.sdf', 'l_out.sdf')
# Out:
# now the small molecule has Hs
# 1

# %%
run_prepare_ligand('l_out.sdf')
# Out:
# 1

# %%
write_vinaconf_gpf('l.pdbqt', 'r.pdbqt', 10)

# %%
! autogrid4 -p r.gpf -l r.glg

# %%
! adgpu --lfile l.pdbqt --ffile r.maps.fld --nrun 50
# Out:
# AutoDock-GPU version: v1.5.3-104-g2e658c318d60806bc6bb361f11f8535d5fb1fe1f
#
# Running 1 docking calculation
#
# Cuda device:                              NVIDIA GeForce MX450
# Available memory on device:               1627 MB (total: 1685 MB)
#
# CUDA Setup time 0.219292s
# (Thread 5 is setting up Job #1)
#
# Running Job #1
#     Using heuristics: (capped) number of evaluations set to 480000
#     Local-search chosen method is: ADADELTA (ad)
#
# Rest of Setup time 0.028699s
#
# Executing docking runs, stopping automatically after either reaching 0.15 kcal/mol standard deviation of
# the best molecules of the last 4 * 5 generations, 42000 generations, or 480000 evaluations:
#
# Generations |  Evaluations |     Threshold    |  Average energy of best 10%  | Samples | Best Inter + Intra
# ------------+--------------+------------------+------------------------------+---------+-------------------
#           0 |          150 |   -0.59 kcal/mol |   -2.11 +/-    0.49 kcal/mol |      12 |   -3.51 kcal/mol
#           5 |        69000 |   -1.51 kcal/mol |   -5.69 +/-    1.59 kcal/mol |    2576 |  -11.53 kcal/mol
#          10 |       159232 |   -5.68 kcal/mol |  -10.08 +/-    0.85 kcal/mol |     182 |  -11.53 kcal/mol
#          15 |       269216 |  -10.01 kcal/mol |  -11.44 +/-    0.08 kcal/mol |      67 |  -11.53 kcal/mol
#          20 |       393277 |  -11.42 kcal/mol |  -11.52 +/-    0.01 kcal/mol |      37 |  -11.53 kcal/mol
#          24 |       496060 |  -11.46 kcal/mol |  -11.52 +/-    0.01 kcal/mol |      37 |  -11.53 kcal/mol
# ------------+--------------+------------------+------------------------------+---------+-------------------
#
#                                    Finished evaluation after reaching
#                         496060 evaluations. Best inter + intra   -11.53 kcal/mol.
#
#
# Shutdown time 0.001172s
#
# Job #1 took 5.019 sec after waiting 0.430 sec for setup
#
# (Thread 5 is processing Job #1)
# Run time of entire job set (1 file): 5.505 sec
# Processing time: 0.052 sec
#
# All jobs ran without errors.

# %%
os.chdir("../mutant/")

# %%
obabel_receptor('./r.pdb')
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ./r.pdb)
#
# 1 molecule converted
# 1

# %%
run_prepare_receptor('./r.pdb')
# Out:
# success
# 1

# %%
! cp ../wild/l.pdbqt ./

# %%
write_vinaconf_gpf('l.pdbqt', 'r.pdbqt', 10)

# %%
run_autogrid('r.gpf')
# Out:
# success, map files created sucsussfully!
# 1

# %%
! adgpu --lfile l.pdbqt --ffile r.maps.fld --nrun 50
# Out:
# AutoDock-GPU version: v1.5.3-104-g2e658c318d60806bc6bb361f11f8535d5fb1fe1f
#
# Running 1 docking calculation
#
# Cuda device:                              NVIDIA GeForce MX450
# Available memory on device:               1627 MB (total: 1685 MB)
#
# CUDA Setup time 0.220304s
# (Thread 5 is setting up Job #1)
#
# Running Job #1
#     Using heuristics: (capped) number of evaluations set to 480000
#     Local-search chosen method is: ADADELTA (ad)
#
# Rest of Setup time 0.027995s
#
# Executing docking runs, stopping automatically after either reaching 0.15 kcal/mol standard deviation of
# the best molecules of the last 4 * 5 generations, 42000 generations, or 480000 evaluations:
#
# Generations |  Evaluations |     Threshold    |  Average energy of best 10%  | Samples | Best Inter + Intra
# ------------+--------------+------------------+------------------------------+---------+-------------------
#           0 |          150 |    1.05 kcal/mol |   -1.36 +/-    0.60 kcal/mol |      32 |   -4.18 kcal/mol
#           5 |        65267 |   -1.08 kcal/mol |   -5.61 +/-    1.49 kcal/mol |    2377 |  -10.24 kcal/mol
#          10 |       149626 |   -5.60 kcal/mol |   -9.26 +/-    0.58 kcal/mol |     117 |  -10.38 kcal/mol
#          15 |       256564 |   -9.19 kcal/mol |  -10.27 +/-    0.07 kcal/mol |      29 |  -10.38 kcal/mol
#          20 |       378472 |  -10.20 kcal/mol |  -10.33 +/-    0.04 kcal/mol |      28 |  -10.38 kcal/mol
#          24 |       481759 |  -10.25 kcal/mol |  -10.37 +/-    0.02 kcal/mol |      32 |  -10.38 kcal/mol
# ------------+--------------+------------------+------------------------------+---------+-------------------
#
#                                    Finished evaluation after reaching
#                         481759 evaluations. Best inter + intra   -10.38 kcal/mol.
#
#
# Shutdown time 0.001171s
#
# Job #1 took 4.853 sec after waiting 0.413 sec for setup
#
# (Thread 5 is processing Job #1)
# Run time of entire job set (1 file): 5.318 sec
# Processing time: 0.052 sec
#
# All jobs ran without errors.

# %%
sav_smiles = "C[C@@H](c1ccc2nccn2c1)n1nnc2ncc(-c3cnn(C)c3)nc21"

# %%
sav_mol = Chem.MolFromSmiles(sav_smiles)

# %%
swiss_df = pd.read_csv("/home/ramin/Downloads/full_out_sav.csv")

# %%
swiss_df.head()
# Out:
#    Unnamed: 0          Phase            S_method    Molecule_ID  Score
# 0         476  CHEMBL_clinic          2D - ECFP4  CHEMBL3334567    1.0
# 1         480  CHEMBL_clinic          2D - MHFP6  CHEMBL3334567    1.0
# 2         487  CHEMBL_clinic  2D - Pharmacophore  CHEMBL3334567    1.0
# 3         521  CHEMBL_clinic            2D - ErG  CHEMBL3334567    1.0
# 4         473  CHEMBL_clinic            2D - FP2  CHEMBL3334567    1.0

# %%
swiss_df.dtypes
# Out:
# Unnamed: 0       int64
# Phase           object
# S_method        object
# Molecule_ID     object
# Score          float64
# dtype: object

# %%
swidd_df = (swiss_df
 .drop('Unnamed: 0', axis=1)
 .drop_duplicates("Molecule_ID")
 .astype({'Phase':'category', 'S_method': 'category', 'Molecule_ID':'string'})
 .query('Phase == "CHEMBL_drug"')
 .drop('Phase', axis=1)
 .reset_index(drop=True)
)

# %%
swiss_df = swidd_df

# %%
swiss_df.head()
# Out:
#             S_method    Molecule_ID  Score
# 0  3D - Electroshape  CHEMBL1257015  0.880
# 1  3D - Electroshape   CHEMBL473417  0.876
# 2  3D - Electroshape  CHEMBL2368925  0.871
# 3  3D - Electroshape  CHEMBL3301607  0.862
# 4  3D - Electroshape     CHEMBL1521  0.862

# %%
swiss_df.shape
# Out:
# (406, 3)

# %%
swiss_df.S_method.unique()
# Out:
# ['3D - Electroshape', '2D - ErG', '2D - Pharmacophore', '2D & 3D combined']
# Categories (6, object): ['2D & 3D combined', '2D - ECFP4', '2D - ErG', '2D - FP2', '2D - Pharmacophore', '3D - Electroshape']

# %%
(swiss_df
 .query("S_method == '2D - Pharmacophore'")
)
# Out:
#               S_method    Molecule_ID  Score
# 62  2D - Pharmacophore  CHEMBL3188267  0.479
# 63  2D - Pharmacophore  CHEMBL3989937  0.479
# 64  2D - Pharmacophore  CHEMBL2107834  0.371
# 65  2D - Pharmacophore  CHEMBL3545376  0.365
# 66  2D - Pharmacophore  CHEMBL3813873  0.350
# 67  2D - Pharmacophore  CHEMBL3989973  0.350

# %%
from chembl_webresource_client.new_client import new_client

# %%
mol = new_client.molecule

# %%
smiles = mol.filter(molecule_chembl_id__in=swiss_df.Molecule_ID.values.tolist()).only('molecule_structures', 'molecule_chembl_id', 'pref_name')

# %%
smiles_list = list(tqdm(smiles))
# Out:
#   0%|          | 0/405 [00:00<?, ?it/s]

# %%
smiles_list_df = pd.DataFrame.from_records(smiles_list)

# %%
smiles_list_df.head()
# Out:
#   molecule_chembl_id                                molecule_structures  \
# 0         CHEMBL6437  {'canonical_smiles': 'CN1CCN2c3ccccc3Cc3ccccc3...
# 1          CHEMBL406  {'canonical_smiles': 'CC1Cc2ccccc2N1NC(=O)c1cc...
# 2          CHEMBL407  {'canonical_smiles': 'CCOC(=O)c1ncn2c1CN(C)C(=...
# 3           CHEMBL12  {'canonical_smiles': 'CN1C(=O)CN=C(c2ccccc2)c2...
# 4           CHEMBL16  {'canonical_smiles': 'O=C1NC(=O)C(c2ccccc2)(c2...
#
#     pref_name
# 0   MIANSERIN
# 1  INDAPAMIDE
# 2  FLUMAZENIL
# 3    DIAZEPAM
# 4   PHENYTOIN

# %%
smiles_list_df['SMILES'] = smiles_list_df.molecule_structures.apply(lambda x: x['canonical_smiles'])

# %%
smiles_list_df.drop('molecule_structures', axis=1, inplace=True)

# %%
smiles_list_df = (smiles_list_df
                  .rename(columns={'molecule_chembl_id': 'Molecule_ID'})
                 )

# %%
swiss_df = pd.merge(
    swiss_df,
    smiles_list_df,
    on='Molecule_ID'
)

# %%
swiss_df.shape
# Out:
# (405, 6)

# %%
swiss_df = (swiss_df
            .drop('SMILES_y', axis=1)
            .rename(columns={'SMILES_x': 'SMILES'})
           )

# %%
swiss_df.head()
# Out:
#             S_method    Molecule_ID  Score  \
# 0  3D - Electroshape  CHEMBL1257015  0.880
# 1  3D - Electroshape   CHEMBL473417  0.876
# 2  3D - Electroshape  CHEMBL2368925  0.871
# 3  3D - Electroshape  CHEMBL3301607  0.862
# 4  3D - Electroshape     CHEMBL1521  0.862
#
#                                               SMILES   pref_name
# 0         COc1ccc(C(=O)NCc2cccnc2)cc1C(=O)NCc1cccnc1  PICOTAMIDE
# 1  CS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccccn3)c2)...  VISMODEGIB
# 2  O=C(O[C@@H]1C[C@@H]2C[C@H]3C[C@H](C1)N2CC3=O)c...  DOLASETRON
# 3  O=C(Nc1nc2cccc(-c3ccc(CN4CCS(=O)(=O)CC4)cc3)n2...  FILGOTINIB
# 4           CCN(C(C)=O)c1cccc(-c2ccnc3c(C#N)cnn23)c1    ZALEPLON

# %%
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(x) for x in swiss_df.SMILES.values[0:10]])

# %%
swiss_df['SMILES'] = (swiss_df
                      .SMILES
                      .apply(lambda x: max(x.split("."), key=len))
                     )

# %%
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(x) for x in swiss_df.SMILES.values[0:10]])

# %%
Chem.MolFromSmiles(swiss_df.query("index == 10").SMILES.values[0])

# %%
swiss_df.SMILES.values[0:10]
# Out:
# array(['COc1ccc(C(=O)NCc2cccnc2)cc1C(=O)NCc1cccnc1',
#        'CS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccccn3)c2)c(Cl)c1',
#        'O=C(O[C@@H]1C[C@@H]2C[C@H]3C[C@H](C1)N2CC3=O)c1c[nH]c2ccccc12',
#        'O=C(Nc1nc2cccc(-c3ccc(CN4CCS(=O)(=O)CC4)cc3)n2n1)C1CC1',
#        'CCN(C(C)=O)c1cccc(-c2ccnc3c(C#N)cnn23)c1',
#        'CCn1c(=O)c(-c2cc(NC(=O)Nc3ccccc3)c(F)cc2Br)cc2cnc(NC)cc21',
#        'CC(=O)SCC(Cc1ccccc1)C(=O)NCC(=O)OCc1ccccc1',
#        'CC(=O)Nc1ccc(OC(=O)c2ccccc2OC(C)=O)cc1',
#        'CCS(=O)(=O)N1CC(CC#N)(n2cc(-c3ncnc4[nH]ccc34)cn2)C1',
#        'Cn1ncnc1[C@H]1c2n[nH]c(=O)c3cc(F)cc(c23)N[C@@H]1c1ccc(F)cc1'],
#       dtype=object)

# %%
swiss_df.query("SMILES == 'Cn1ncnc1[C@H]1c2n[nH]c(=O)c3cc(F)cc(c23)N[C@@H]1c1ccc(F)cc1'")
# Out:
#              S_method    Molecule_ID  Score  \
# 9   3D - Electroshape  CHEMBL3137318  0.856
# 19  3D - Electroshape  CHEMBL3137320  0.849
#
#                                                SMILES             pref_name
# 9   Cn1ncnc1[C@H]1c2n[nH]c(=O)c3cc(F)cc(c23)N[C@@H...  TALAZOPARIB TOSYLATE
# 19  Cn1ncnc1[C@H]1c2n[nH]c(=O)c3cc(F)cc(c23)N[C@@H...           TALAZOPARIB

# %% [markdown]
# ### Lig docking

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE_lgbm

# %%
ligands_df = pd.read_csv("./../cleaner_to_dock_lgbm.csv")

# %%
ligands_df.head()
# Out:
#                      name                                             SMILES
# 0               Midazolam    CC1=NC=C2CN=C(C3=CC=CC=C3F)C3=C(C=CC(Cl)=C3)N12
# 1             Rabeprazole      COCCCOC1=C(C)C(CS(=O)C2=NC3=CC=CC=C3N2)=NC=C1
# 2             Roflumilast  FC(F)OC1=C(OCC2CC2)C=C(C=C1)C(=O)NC1=C(Cl)C=NC...
# 3  7-Hydroxystaurosporine  [H][C@]12C[C@@H](NC)[C@@H](OC)[C@](C)(O1)N1C3=...
# 4              Piritrexim   COC1=CC(CC2=C(C)C3=C(N=C2)N=C(N)N=C3N)=C(OC)C=C1

# %%
ligands_df['mol'] = ligands_df['SMILES'].apply(Chem.MolFromSmiles)

# %%
ligands_df.head()
# Out:
#                      name                                             SMILES  \
# 0               Midazolam    CC1=NC=C2CN=C(C3=CC=CC=C3F)C3=C(C=CC(Cl)=C3)N12
# 1             Rabeprazole      COCCCOC1=C(C)C(CS(=O)C2=NC3=CC=CC=C3N2)=NC=C1
# 2             Roflumilast  FC(F)OC1=C(OCC2CC2)C=C(C=C1)C(=O)NC1=C(Cl)C=NC...
# 3  7-Hydroxystaurosporine  [H][C@]12C[C@@H](NC)[C@@H](OC)[C@](C)(O1)N1C3=...
# 4              Piritrexim   COC1=CC(CC2=C(C)C3=C(N=C2)N=C(N)N=C3N)=C(OC)C=C1
#
#                                                 mol    db
# 0  <rdkit.Chem.rdchem.Mol object at 0x713fc1cd7370>  db_0
# 1  <rdkit.Chem.rdchem.Mol object at 0x713fc1cd73e0>  db_1
# 2  <rdkit.Chem.rdchem.Mol object at 0x713fc1cd71b0>  db_2
# 3  <rdkit.Chem.rdchem.Mol object at 0x713fc1cd7220>  db_3
# 4  <rdkit.Chem.rdchem.Mol object at 0x713fc1cd7450>  db_4

# %%
ligands_df.values[0][2]

# %%
ligands_df['db'] = [f"db_{x}" for x in range(len(ligands_df))]

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE_lgbm

# %%
failed = []
for row in ligands_df.values:
    os.mkdir(row[3])
    try:
        ligand_prep(row[2], out=f"{row[3]}/l")
    except Exception as e:
        os.removedirs(row[0])
        failed.append(row)

# %%
len(failed)
# Out:
# 0

# %% [markdown]
# ##### dock for wild type

# %%
len([x for x in os.listdir() if x.startswith('db')])
# Out:
# 173

# %%
os.path.exists('db_0/l.pdbqt')
# Out:
# True

# %%
import shutil
import glob

# %%
([x for x in os.listdir() if x.startswith("CH")][0])
# Out:
# True

# %%
os.getcwd()
# Out:
# '/home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE'

# %%
for dir_ in [x for x in os.listdir() if x.startswith("CH")]:
    for file in glob.glob('./wild/r.*'): 
        shutil.copy2(file, dir_)

# %% [markdown]
# wrtie gpf to wild types

# %%
os.getcwd()
# Out:
# '/home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE'

# %%
from tqdm.auto import tqdm

# %%
to_dock_dirs = [x for x in os.listdir() if x.startswith("db")]

# %%
os.getcwd()
# Out:
# '/home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE_lgbm'

# %%
os.path.exists('db_0/l_wild.dlg')
# Out:
# True

# %%
import time
#os.chdir('./savolotinib_6SDE/')

# %%
os.path.exists('./wild/cocrystall_ligand/r.maps.fld')
# Out:
# True

# %%
for idx, dir_ in enumerate(tqdm(to_dock_dirs, total=len(to_dock_dirs))):
    #if (idx>240 and idx%10 == 0):
    #    print('cooling down')
    #    time.sleep(20)
    
    if not os.path.exists(f'{dir_}/l_wild.dlg'):
        os.chdir(dir_)
        print(f"Docking in {dir_}")
        command = f"/home/ramin/Desktop/personal/cheminfo/adgpu --lfile l.pdbqt --ffile ../wild/cocrystall_ligand/r.maps.fld --nrun 50 --resnam l_wild"
        try:
            
            result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            #print(f"Command output: {result.stdout}")
            if result.stderr:
                print(f"Command stderr: {str(result.stderr)}")
        except subprocess.CalledProcessError as e:
            print(f"Command failed with error: {e}")
            print(f"Error output: {e.stderr}")

        os.chdir('../')  
    else:
        pass
# Out:
#   0%|          | 0/173 [00:00<?, ?it/s]
# Docking in db_1
# Docking in db_2
# Docking in db_3
# Docking in db_4
# Docking in db_5
# Docking in db_6
# Docking in db_7
# Docking in db_8
# Docking in db_9
# Docking in db_10
# Docking in db_11
# Docking in db_12
# Docking in db_13
# Docking in db_14
# Docking in db_15
# Docking in db_16
# Docking in db_17
# Docking in db_18
# Docking in db_19
# Docking in db_20
# Docking in db_21
# Docking in db_22
# Docking in db_23
# Docking in db_24
# Docking in db_25
# Docking in db_26
# Docking in db_27
# Docking in db_28
# Docking in db_29
# Docking in db_30
# Docking in db_31
# Docking in db_32
# Docking in db_33
# Docking in db_34
# Docking in db_35
# Docking in db_36
# Docking in db_37
# Docking in db_38
# Docking in db_39
# Docking in db_40
# Docking in db_41
# Docking in db_42
# Docking in db_43
# Docking in db_44
# Docking in db_45
# Docking in db_46
# Docking in db_47
# Docking in db_48
# Docking in db_49
# Docking in db_50
# Docking in db_51
# Docking in db_52
# Docking in db_53
# Docking in db_54
# Docking in db_55
# Docking in db_56
# Docking in db_57
# Docking in db_58
# Docking in db_59
# Docking in db_60
# Docking in db_61
# Docking in db_62
# Docking in db_63
# Docking in db_64
# Docking in db_65
# Docking in db_66
# Docking in db_67
# Docking in db_68
# Docking in db_69
# Docking in db_70
# Docking in db_71
# Docking in db_72
# Docking in db_73
# Docking in db_74
# Docking in db_75
# Docking in db_76
# Docking in db_77
# Docking in db_78
# Docking in db_79
# Docking in db_80
# Docking in db_81
# Docking in db_82
# Docking in db_83
# Docking in db_84
# Docking in db_85
# Docking in db_86
# Docking in db_87
# Docking in db_88
# Docking in db_89
# Docking in db_90
# Docking in db_91
# Docking in db_92
# Docking in db_93
# Docking in db_94
# Docking in db_95
# Docking in db_96
# Docking in db_97
# Docking in db_98
# Docking in db_99
# Docking in db_100
# Docking in db_101
# Docking in db_102
# Docking in db_103
# Docking in db_104
# Docking in db_105
# Docking in db_106
# Docking in db_107
# Docking in db_108
# Docking in db_109
# Docking in db_110
# Docking in db_111
# Docking in db_112
# Docking in db_113
# Docking in db_114
# Docking in db_115
# Docking in db_116
# Docking in db_117
# Docking in db_118
# Docking in db_119
# Docking in db_120
# Docking in db_121
# Docking in db_122
# Docking in db_123
# Docking in db_124
# Docking in db_125
# Docking in db_126
# Docking in db_127
# Docking in db_128
# Docking in db_129
# Docking in db_130
# Docking in db_131
# Docking in db_132
# Docking in db_133
# Docking in db_134
# Docking in db_135
# Docking in db_136
# Docking in db_137
# Docking in db_138
# Docking in db_139
# Docking in db_140
# Docking in db_141
# Docking in db_142
# Docking in db_143
# Docking in db_144
# Docking in db_145
# Docking in db_146
# Docking in db_147
# Docking in db_148
# Docking in db_149
# Docking in db_150
# Docking in db_151
# Docking in db_152
# Docking in db_153
# Docking in db_154
# Docking in db_155
# Docking in db_156
# Docking in db_157
# Docking in db_158
# Docking in db_159
# Docking in db_160
# Docking in db_161
# Docking in db_162
# Docking in db_163
# Docking in db_164
# Docking in db_165
# Docking in db_166
# Docking in db_167
# Docking in db_168
# Docking in db_169
# Docking in db_170
# Docking in db_171
# Docking in db_172

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE_lgbm

# %%
os.chdir('../')

# %%
os.path.exists('db_0/l_wild.dlg')
# Out:
# True

# %%
os.getcwd()
# Out:
# '/home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE_lgbm'

# %%
os.chdir('./savolotinib_6SDE/')

# %%
data = []
for dir__ in [x for x in os.listdir() if x.startswith('db')]:
    if os.path.exists(f'{dir__}/l_wild.dlg'):
        lines = []
        with open(f'{dir__}/l_wild.dlg') as f:
            lines = f.readlines()
        eng = [float(lines[idx+4].split("|")[1].strip()) for idx,x in enumerate(lines) if x.startswith('Clus')][0]
        data.append((dir__, eng))

# %%
data = pd.DataFrame.from_records([x for x in data], columns=['db', 'deltaG'])

# %%
data.sort_values('deltaG').head()
# Out:
#          db  deltaG
# 97    db_97  -12.00
# 153  db_153  -11.34
# 109  db_109  -11.30
# 113  db_113  -10.97
# 59    db_59  -10.93

# %%
data.head()
# Out:
#      db  deltaG
# 0  db_0   -8.01
# 1  db_1   -7.32
# 2  db_2   -7.78
# 3  db_3   -9.67
# 4  db_4   -7.24

# %%
data.to_csv("DeltaG_on_wild.csv", index=False)

# %%
(ligands_df
 .query("db in @ligands_df.db.values")
 .assign(
     deltaG = data.deltaG.values
 )
 [['name', 'deltaG', 'SMILES']]
 .sort_values('deltaG')
 
).to_csv('docked.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=data.index.values,y=data.deltaG.values, alpha=0.8, label='Drugs')
plt.yticks(range(-13,0))
plt.ylabel('Delta G')
plt.xticks([])
plt.hlines(y=float(-9.95), xmin=0, xmax=1000, lw=3, colors='red', label='Cocrystall ligand')
plt.legend()
plt.show()
#plt.gca().invert_yaxis()

# %% [markdown]
# ### Docking the better ones on the mutant form

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met

# %%
os.chdir('./savolotinib_6SDE/')

# %%
ligands_m_df = pd.read_csv('./better_than_cocrystall.csv')

# %%
ligands_m_df.head()
# Out:
#             name       method  deltaG     score  \
# 0      TEPOTINIB  dice_morgan  -12.38  0.280702
# 1     CAPMATINIB        swiss  -11.39  0.479000
# 2       IMATINIB  dice_morgan  -11.37  0.239316
# 3    BELUMOSUDIL  dice_morgan  -11.32  0.245614
# 4  ACALABRUTINIB  dice_morgan  -11.06  0.288136
#
#                                               SMILES
# 0  CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)cc...
# 1  CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 2  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3  CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 4  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...

# %%
ligands_m_df = ligands_m_df.rename(columns={'deltaG': 'deltaG_wild'})

# %%
ligands_m_df['mol'] = ligands_m_df.SMILES.apply(Chem.MolFromSmiles)

# %%
ligands_m_df.head()
# Out:
#             name       method  deltaG_wild     score  \
# 0      TEPOTINIB  dice_morgan       -12.38  0.280702
# 1     CAPMATINIB        swiss       -11.39  0.479000
# 2       IMATINIB  dice_morgan       -11.37  0.239316
# 3    BELUMOSUDIL  dice_morgan       -11.32  0.245614
# 4  ACALABRUTINIB  dice_morgan       -11.06  0.288136
#
#                                               SMILES  \
# 0  CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)cc...
# 1  CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 2  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3  CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 4  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
#
#                                                 mol
# 0  <rdkit.Chem.rdchem.Mol object at 0x7153260747b0>
# 1  <rdkit.Chem.rdchem.Mol object at 0x715326074ac0>
# 2  <rdkit.Chem.rdchem.Mol object at 0x715326074c10>
# 3  <rdkit.Chem.rdchem.Mol object at 0x715326074890>
# 4  <rdkit.Chem.rdchem.Mol object at 0x715326074820>

# %%
ligands_m_df.values[5][5]

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE

# %%
failed = []
for row in ligands_m_df.values:
    os.mkdir(f"{row[0]}_mutant")
    try:
        ligand_prep(row[5], out=f"{row[0]}_mutant/l")
    except Exception as e:
        os.removedirs(row[0])
        failed.append(row)

# %%
import glob, shutil

# %%
os.getcwd()
# Out:
# '/home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE'

# %%
for dir_ in [x for x in os.listdir() if x.endswith('mutant')]:
    for file in glob.glob('./mutant/r.*'):
        try:
            shutil.copy2(file, dir_)
        except shutil.SameFileError:
            pass

# %%
to_dock_dirs = [x for x in os.listdir() if x.endswith("_mutant")]

# %%
to_dock_dirs
# Out:
# ['TEPOTINIB_mutant',
#  'CAPMATINIB_mutant',
#  'IMATINIB_mutant',
#  'BELUMOSUDIL_mutant',
#  'ACALABRUTINIB_mutant',
#  'RISPERIDONE_mutant',
#  'PRANLUKAST_mutant',
#  'IRBESARTAN_mutant',
#  'PALIPERIDONE_mutant',
#  'VIBEGRON_mutant',
#  'OLAPARIB_mutant',
#  'AXITINIB_mutant',
#  'LOSARTAN_mutant',
#  'MITAPIVAT_mutant',
#  'ZANUBRUTINIB_mutant',
#  'DOMPERIDONE_mutant',
#  'DROPERIDOL_mutant',
#  'TRILACICLIB_mutant',
#  'VILAZODONE_mutant',
#  'LINAGLIPTIN_mutant',
#  'ZIPRASIDONE_mutant',
#  'GLIPIZIDE_mutant',
#  'THIOTHIXENE_mutant',
#  'CABERGOLINE_mutant',
#  'LURASIDONE_mutant',
#  'ELETRIPTAN_mutant',
#  'PIPERACETAZINE_mutant',
#  'CILOSTAZOL_mutant',
#  'RISDIPLAM_mutant',
#  'NETARSUDIL_mutant',
#  'DARIFENACIN_mutant',
#  'ELTROMBOPAG_mutant',
#  'PIPAMAZINE_mutant',
#  'DUVELISIB_mutant',
#  'FLAVOXATE_mutant',
#  'NEFAZODONE_mutant',
#  'PANOBINOSTAT_mutant',
#  'LAROTRECTINIB_mutant',
#  'KETANSERIN_mutant']

# %%
import time

# %%
for idx, dir_ in enumerate(tqdm(to_dock_dirs, total=len(to_dock_dirs))):
    if (idx%10 == 0):
        print('cooling down')
        time.sleep(20)
    
    if not os.path.exists(f'{dir_}/l_mutant.dlg'):
        os.chdir(dir_)
        print(f"Docking in {dir_}")
        command = f"/home/ramin/Downloads/AutoDock-GPU/bin/autodock_gpu_64wi --lfile l.pdbqt --ffile r.maps.fld --nrun 50 --resnam l_mutant"
        try:
            
            result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            #print(f"Command output: {result.stdout}")
            if result.stderr:
                print(f"Command stderr: {str(result.stderr)}")
        except subprocess.CalledProcessError as e:
            print(f"Command failed with error: {e}")
            print(f"Error output: {e.stderr}")

        os.chdir('../')
    else:
        pass
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# cooling down
# Docking in TEPOTINIB_mutant
# Docking in CAPMATINIB_mutant
# Docking in IMATINIB_mutant
# Docking in BELUMOSUDIL_mutant
# Docking in ACALABRUTINIB_mutant
# Docking in RISPERIDONE_mutant
# Docking in PRANLUKAST_mutant
# Docking in IRBESARTAN_mutant
# Docking in PALIPERIDONE_mutant
# Docking in VIBEGRON_mutant
# cooling down
# Docking in OLAPARIB_mutant
# Docking in AXITINIB_mutant
# Docking in LOSARTAN_mutant
# Docking in MITAPIVAT_mutant
# Docking in ZANUBRUTINIB_mutant
# Docking in DOMPERIDONE_mutant
# Docking in DROPERIDOL_mutant
# Docking in TRILACICLIB_mutant
# Docking in VILAZODONE_mutant
# Docking in LINAGLIPTIN_mutant
# cooling down
# Docking in ZIPRASIDONE_mutant
# Docking in GLIPIZIDE_mutant
# Docking in THIOTHIXENE_mutant
# Docking in CABERGOLINE_mutant
# Docking in LURASIDONE_mutant
# Docking in ELETRIPTAN_mutant
# Docking in PIPERACETAZINE_mutant
# Docking in CILOSTAZOL_mutant
# Docking in RISDIPLAM_mutant
# Docking in NETARSUDIL_mutant
# cooling down
# Docking in DARIFENACIN_mutant
# Docking in ELTROMBOPAG_mutant
# Docking in PIPAMAZINE_mutant
# Docking in DUVELISIB_mutant
# Docking in FLAVOXATE_mutant
# Docking in NEFAZODONE_mutant
# Docking in PANOBINOSTAT_mutant
# Docking in LAROTRECTINIB_mutant
# Docking in KETANSERIN_mutant

# %%
! pwd
# Out:
# /home/ramin/Desktop/personal/cheminfo/met/savolotinib_6SDE

# %%
data_m = []
for dir__ in [x for x in os.listdir() if x.endswith('_mutant')]:
    if os.path.exists(f'{dir__}/l_mutant.dlg'):
        lines = []
        with open(f'{dir__}/l_mutant.dlg') as f:
            lines = f.readlines()
        eng = [float(lines[idx+4].split("|")[1].strip()) for idx,x in enumerate(lines) if x.startswith('Clus')][0]
        data_m.append((dir__.split('_')[0], eng))

# %%
new_data = pd.DataFrame.from_records(data_m, columns=['name', 'deltaG_mutant'])

# %%
ligands_m_df.head()
# Out:
#             name       method  deltaG_wild     score  \
# 0      TEPOTINIB  dice_morgan       -12.38  0.280702
# 1     CAPMATINIB        swiss       -11.39  0.479000
# 2       IMATINIB  dice_morgan       -11.37  0.239316
# 3    BELUMOSUDIL  dice_morgan       -11.32  0.245614
# 4  ACALABRUTINIB  dice_morgan       -11.06  0.288136
#
#                                               SMILES  \
# 0  CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)cc...
# 1  CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 2  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3  CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 4  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
#
#                                                 mol
# 0  <rdkit.Chem.rdchem.Mol object at 0x7153944b3300>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7153944b3060>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7153944b3760>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7153944b14d0>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7153944b36f0>

# %%
both_mu_wi = pd.merge(
    ligands_m_df,
    new_data,
    on='name'
)

# %%
both_mu_wi
# Out:
#               name       method  deltaG_wild     score  \
# 0        TEPOTINIB  dice_morgan       -12.38  0.280702
# 1       CAPMATINIB        swiss       -11.39  0.479000
# 2         IMATINIB  dice_morgan       -11.37  0.239316
# 3      BELUMOSUDIL  dice_morgan       -11.32  0.245614
# 4    ACALABRUTINIB  dice_morgan       -11.06  0.288136
# 5      RISPERIDONE   dice_maccs       -10.89  0.604167
# 6       PRANLUKAST   dice_maccs       -10.84  0.595745
# 7       IRBESARTAN  dice_morgan       -10.78  0.201835
# 8     PALIPERIDONE   dice_maccs       -10.78  0.557692
# 9         VIBEGRON   dice_maccs       -10.69  0.549451
# 10        OLAPARIB        swiss       -10.63  0.843000
# 11        AXITINIB  dice_morgan       -10.62  0.211538
# 12        LOSARTAN  dice_morgan       -10.56  0.211538
# 13       MITAPIVAT   dice_maccs       -10.52  0.500000
# 14    ZANUBRUTINIB   dice_maccs       -10.51  0.594059
# 15     DOMPERIDONE   dice_maccs       -10.44  0.559140
# 16      DROPERIDOL   dice_maccs       -10.43  0.541667
# 17     TRILACICLIB  dice_morgan       -10.41  0.272727
# 18      VILAZODONE   dice_maccs       -10.39  0.551724
# 19     LINAGLIPTIN        swiss       -10.37  0.767000
# 20     ZIPRASIDONE   dice_maccs       -10.36  0.571429
# 21       GLIPIZIDE   dice_maccs       -10.33  0.427184
# 22     THIOTHIXENE   dice_maccs       -10.32  0.520000
# 23     CABERGOLINE   dice_maccs       -10.32  0.562500
# 24      LURASIDONE   dice_maccs       -10.31  0.608696
# 25      ELETRIPTAN   dice_maccs       -10.30  0.531915
# 26  PIPERACETAZINE   dice_maccs       -10.29  0.506024
# 27      CILOSTAZOL   dice_maccs       -10.27  0.652632
# 28       RISDIPLAM        swiss       -10.25  0.758000
# 29      NETARSUDIL  dice_morgan       -10.22  0.218182
# 30     DARIFENACIN   dice_maccs       -10.21  0.481928
# 31     ELTROMBOPAG   dice_maccs       -10.13  0.577778
# 32      PIPAMAZINE   dice_maccs       -10.11  0.476190
# 33       DUVELISIB  dice_morgan       -10.10  0.259259
# 34       FLAVOXATE   dice_maccs       -10.09  0.452381
# 35      NEFAZODONE   dice_maccs       -10.07  0.574257
# 36    PANOBINOSTAT   dice_maccs       -10.04  0.436782
# 37   LAROTRECTINIB  dice_morgan       -10.00  0.216216
# 38      KETANSERIN        swiss        -9.96  0.832000
#
#                                                SMILES  \
# 0   CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)cc...
# 1   CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 2   Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3   CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 4   CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
# 5   Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2
# 6   O=C(Nc1cccc2c(=O)cc(-c3nnn[nH]3)oc12)c1ccc(OCC...
# 7   CCCCC1=NC2(CCCC2)C(=O)N1Cc1ccc(-c2ccccc2-c2nnn...
# 8   Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CC...
# 9   O=C(Nc1ccc(C[C@@H]2CC[C@H]([C@H](O)c3ccccc3)N2...
# 10  O=C(c1cc(Cc2n[nH]c(=O)c3ccccc23)ccc1F)N1CCN(C(...
# 11    CNC(=O)c1ccccc1Sc1ccc2c(/C=C/c3ccccn3)n[nH]c2c1
# 12  CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nnn[nH]2...
# 13  O=C(c1ccc(NS(=O)(=O)c2cccc3cccnc23)cc1)N1CCN(C...
# 14  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 15  O=c1[nH]c2ccccc2n1CCCN1CCC(n2c(=O)[nH]c3cc(Cl)...
# 16  O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F...
# 17  CN1CCN(c2ccc(Nc3ncc4cc5n(c4n3)C3(CCCCC3)CNC5=O...
# 18  N#Cc1ccc2[nH]cc(CCCCN3CCN(c4ccc5oc(C(N)=O)cc5c...
# 19  CC#CCn1c(N2CCC[C@@H](N)C2)nc2c1c(=O)n(Cc1nc(C)...
# 20     O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1
# 21  Cc1cnc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)...
# 22  CN1CCN(CC/C=C2/c3ccccc3Sc3ccc(S(=O)(=O)N(C)C)c...
# 23  C=CCN1C[C@H](C(=O)N(CCCN(C)C)C(=O)NCC)C[C@@H]2...
# 24  O=C1[C@@H]2[C@H]3CC[C@H](C3)[C@@H]2C(=O)N1C[C@...
# 25  CN1CCC[C@@H]1Cc1c[nH]c2ccc(CCS(=O)(=O)c3ccccc3...
# 26     CC(=O)c1ccc2c(c1)N(CCCN1CCC(CCO)CC1)c1ccccc1S2
# 27             O=C1CCc2cc(OCCCCc3nnnn3C3CCCCC3)ccc2N1
# 28  Cc1cn2nc(-c3cc(=O)n4cc(N5CCNC6(CC6)C5)ccc4n3)c...
# 29  Cc1ccc(C(=O)OCc2ccc([C@@H](CN)C(=O)Nc3ccc4cncc...
# 30  NC(=O)C(c1ccccc1)(c1ccccc1)[C@@H]1CCN(CCc2ccc3...
# 31  CC1=NN(c2ccc(C)c(C)c2)C(=O)/C1=N\Nc1cccc(-c2cc...
# 32        NC(=O)C1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1
# 33  C[C@H](Nc1ncnc2nc[nH]c12)c1cc2cccc(Cl)c2c(=O)n...
# 34     Cc1c(-c2ccccc2)oc2c(C(=O)OCCN3CCCCC3)cccc2c1=O
# 35  CCc1nn(CCCN2CCN(c3cccc(Cl)c3)CC2)c(=O)n1CCOc1c...
# 36        Cc1[nH]c2ccccc2c1CCNCc1ccc(/C=C/C(=O)NO)cc1
# 37  O=C(Nc1cnn2ccc(N3CCC[C@@H]3c3cc(F)ccc3F)nc12)N...
# 38  O=C(c1ccc(F)cc1)C1CCN(CCn2c(=O)[nH]c3ccccc3c2=...
#
#                                                  mol  deltaG_mutant
# 0   <rdkit.Chem.rdchem.Mol object at 0x7153260747b0>         -10.22
# 1   <rdkit.Chem.rdchem.Mol object at 0x715326074ac0>         -10.25
# 2   <rdkit.Chem.rdchem.Mol object at 0x715326074c10>         -10.07
# 3   <rdkit.Chem.rdchem.Mol object at 0x715326074890>         -11.10
# 4   <rdkit.Chem.rdchem.Mol object at 0x715326074820>          -8.61
# 5   <rdkit.Chem.rdchem.Mol object at 0x7153260749e0>          -9.91
# 6   <rdkit.Chem.rdchem.Mol object at 0x715326074900>         -10.03
# 7   <rdkit.Chem.rdchem.Mol object at 0x715326074b30>         -11.11
# 8   <rdkit.Chem.rdchem.Mol object at 0x715326074ba0>          -9.64
# 9   <rdkit.Chem.rdchem.Mol object at 0x715326074c80>          -9.38
# 10  <rdkit.Chem.rdchem.Mol object at 0x715326074cf0>         -10.61
# 11  <rdkit.Chem.rdchem.Mol object at 0x715326074d60>          -9.79
# 12  <rdkit.Chem.rdchem.Mol object at 0x715326074dd0>         -11.10
# 13  <rdkit.Chem.rdchem.Mol object at 0x715326074e40>          -9.43
# 14  <rdkit.Chem.rdchem.Mol object at 0x715326074eb0>          -9.66
# 15  <rdkit.Chem.rdchem.Mol object at 0x715326074f20>          -9.32
# 16  <rdkit.Chem.rdchem.Mol object at 0x715326074f90>          -9.61
# 17  <rdkit.Chem.rdchem.Mol object at 0x715326075000>          -8.29
# 18  <rdkit.Chem.rdchem.Mol object at 0x715326075070>          -9.53
# 19  <rdkit.Chem.rdchem.Mol object at 0x7153260750e0>          -9.04
# 20  <rdkit.Chem.rdchem.Mol object at 0x715326075150>          -9.63
# 21  <rdkit.Chem.rdchem.Mol object at 0x7153260751c0>          -9.56
# 22  <rdkit.Chem.rdchem.Mol object at 0x715326075230>          -9.14
# 23  <rdkit.Chem.rdchem.Mol object at 0x7153260752a0>          -9.24
# 24  <rdkit.Chem.rdchem.Mol object at 0x715326075310>         -10.67
# 25  <rdkit.Chem.rdchem.Mol object at 0x715326075380>          -9.24
# 26  <rdkit.Chem.rdchem.Mol object at 0x7153260753f0>          -9.08
# 27  <rdkit.Chem.rdchem.Mol object at 0x715326075460>         -10.45
# 28  <rdkit.Chem.rdchem.Mol object at 0x7153260754d0>          -9.52
# 29  <rdkit.Chem.rdchem.Mol object at 0x715326075540>         -10.08
# 30  <rdkit.Chem.rdchem.Mol object at 0x7153260755b0>         -10.05
# 31  <rdkit.Chem.rdchem.Mol object at 0x715326075620>          -9.71
# 32  <rdkit.Chem.rdchem.Mol object at 0x715326075690>          -9.51
# 33  <rdkit.Chem.rdchem.Mol object at 0x715326075700>          -9.72
# 34  <rdkit.Chem.rdchem.Mol object at 0x715326075770>          -9.08
# 35  <rdkit.Chem.rdchem.Mol object at 0x7153260757e0>         -10.37
# 36  <rdkit.Chem.rdchem.Mol object at 0x715326075850>          -9.52
# 37  <rdkit.Chem.rdchem.Mol object at 0x7153260758c0>          -9.74
# 38  <rdkit.Chem.rdchem.Mol object at 0x715326075930>          -8.93

# %%
plt.scatter(x=both_mu_wi.index.values,y=both_mu_wi.deltaG_mutant.values, alpha=0.8, label='Drugs')
plt.yticks(range(-13,0))
plt.ylabel('Delta G')
plt.xticks([])
plt.hlines(y=float(-8.80), xmin=0, xmax=1000, lw=3, colors='red', label='Cocrystall ligand')
plt.legend()
plt.show()

# %%
both_mu_wi.query('deltaG_wild > deltaG_mutant')[['name', 'deltaG_wild', 'deltaG_mutant']]
# Out:
#           name  deltaG_wild  deltaG_mutant
# 7   IRBESARTAN       -10.78         -11.11
# 12    LOSARTAN       -10.56         -11.10
# 24  LURASIDONE       -10.31         -10.67
# 27  CILOSTAZOL       -10.27         -10.45
# 35  NEFAZODONE       -10.07         -10.37

# %%
legends = [x[1] for x in both_mu_wi.sort_values('deltaG_mutant').head().iterrows()]

# %%
Chem.Draw.MolsToGridImage([*both_mu_wi.sort_values('deltaG_mutant').head().mol.values[0:3], sav_mol], 
                          legends=[*[f"{x['name']}, wildG: {x['deltaG_wild']}, mutantG: {x['deltaG_mutant']}" for x in legends[0:3]], 'Corystall ligand, wildG: -9.95, mutantG: -8.80'])

# %%
both_mu_wi.to_csv("./wild_mutant.csv", index=False)

# %%
both_mu_wi.head()
# Out:
#             name       method  deltaG_wild     score  \
# 0      TEPOTINIB  dice_morgan       -12.38  0.280702
# 1     CAPMATINIB        swiss       -11.39  0.479000
# 2       IMATINIB  dice_morgan       -11.37  0.239316
# 3    BELUMOSUDIL  dice_morgan       -11.32  0.245614
# 4  ACALABRUTINIB  dice_morgan       -11.06  0.288136
#
#                                               SMILES  \
# 0  CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)cc...
# 1  CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 2  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3  CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 4  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
#
#                                                 mol  deltaG_mutant
# 0  <rdkit.Chem.rdchem.Mol object at 0x7153260747b0>         -10.22
# 1  <rdkit.Chem.rdchem.Mol object at 0x715326074ac0>         -10.25
# 2  <rdkit.Chem.rdchem.Mol object at 0x715326074c10>         -10.07
# 3  <rdkit.Chem.rdchem.Mol object at 0x715326074890>         -11.10
# 4  <rdkit.Chem.rdchem.Mol object at 0x715326074820>          -8.61

# %%
df = pd.read_csv('./savolotinib_6SDE/wild_mutant.csv')

# %%
df.head()
# Out:
#             name       method  deltaG_wild     score  \
# 0      TEPOTINIB  dice_morgan       -12.38  0.280702
# 1     CAPMATINIB        swiss       -11.39  0.479000
# 2       IMATINIB  dice_morgan       -11.37  0.239316
# 3    BELUMOSUDIL  dice_morgan       -11.32  0.245614
# 4  ACALABRUTINIB  dice_morgan       -11.06  0.288136
#
#                                               SMILES  \
# 0  CN1CCC(COc2cnc(-c3cccc(Cn4nc(-c5cccc(C#N)c5)cc...
# 1  CNC(=O)c1ccc(-c2cnc3ncc(Cc4ccc5ncccc5c4)n3n2)cc1F
# 2  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3  CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 4  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
#
#                                                 mol  deltaG_mutant
# 0  <rdkit.Chem.rdchem.Mol object at 0x7153260747b0>         -10.22
# 1  <rdkit.Chem.rdchem.Mol object at 0x715326074ac0>         -10.25
# 2  <rdkit.Chem.rdchem.Mol object at 0x715326074c10>         -10.07
# 3  <rdkit.Chem.rdchem.Mol object at 0x715326074890>         -11.10
# 4  <rdkit.Chem.rdchem.Mol object at 0x715326074820>          -8.61

# %%
df = df.sort_values('deltaG_mutant')
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#           name       method  deltaG_wild     score  \
# 0   IRBESARTAN  dice_morgan       -10.78  0.201835
# 1  BELUMOSUDIL  dice_morgan       -11.32  0.245614
# 2     LOSARTAN  dice_morgan       -10.56  0.211538
# 3   LURASIDONE   dice_maccs       -10.31  0.608696
# 4     OLAPARIB        swiss       -10.63  0.843000
#
#                                               SMILES  \
# 0  CCCCC1=NC2(CCCC2)C(=O)N1Cc1ccc(-c2ccccc2-c2nnn...
# 1  CC(C)NC(=O)COc1cccc(-c2nc(Nc3ccc4[nH]ncc4c3)c3...
# 2  CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nnn[nH]2...
# 3  O=C1[C@@H]2[C@H]3CC[C@H](C3)[C@@H]2C(=O)N1C[C@...
# 4  O=C(c1cc(Cc2n[nH]c(=O)c3ccccc23)ccc1F)N1CCN(C(...
#
#                                                 mol  deltaG_mutant
# 0  <rdkit.Chem.rdchem.Mol object at 0x715326074b30>         -11.11
# 1  <rdkit.Chem.rdchem.Mol object at 0x715326074890>         -11.10
# 2  <rdkit.Chem.rdchem.Mol object at 0x715326074dd0>         -11.10
# 3  <rdkit.Chem.rdchem.Mol object at 0x715326075310>         -10.67
# 4  <rdkit.Chem.rdchem.Mol object at 0x715326074cf0>         -10.61

# %%
df.query("deltaG_mutant < deltaG_wild").SMILES.to_list()
# Out:
# ['CCCCC1=NC2(CCCC2)C(=O)N1Cc1ccc(-c2ccccc2-c2nnn[nH]2)cc1',
#  'CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nnn[nH]2)cc1',
#  'O=C1[C@@H]2[C@H]3CC[C@H](C3)[C@@H]2C(=O)N1C[C@@H]1CCCC[C@H]1CN1CCN(c2nsc3ccccc23)CC1',
#  'O=C1CCc2cc(OCCCCc3nnnn3C3CCCCC3)ccc2N1',
#  'CCc1nn(CCCN2CCN(c3cccc(Cl)c3)CC2)c(=O)n1CCOc1ccccc1']

# %%
df.query("name == 'IRBESARTAN'").SMILES.values[0]
# Out:
# 'CCCCC1=NC2(CCCC2)C(=O)N1Cc1ccc(-c2ccccc2-c2nnn[nH]2)cc1'
